# %% [markdown]
# # Field Study Project (Part 3 : Building Mix Dataset)
# ## Athens University of Economics and Business
# ## Msc in Business Analytics
# ## Written by : Xheni Cobanaj (f2822117)
# ## Supervisor : Mr Damianos Chatziantoniou
# ## Topic : Customer Segmentation of Food Delivery App

# %%
pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 6.2 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.6

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# importing all necessary modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from IPython.display import Image
from IPython.core.display import HTML 
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats
from datetime import datetime
import re
import itertools
from itertools import product
import string

# For getting optimal number of clusters in hierarchical clustering
from scipy.cluster.hierarchy import dendrogram,linkage
# To scale the data
from sklearn.preprocessing import MinMaxScaler,StandardScaler
# metrics to evaluate the clusters
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Clustering alorithms
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
import plotly as py
import plotly.graph_objs as go
from unidecode import unidecode
from datetime import datetime
# activating DND to disregard the warnings by goiing silent mode
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read Data

# %%
df = pd.read_csv("/content/drive/MyDrive/preprocessed_data.csv",header=0,parse_dates= ['order_timestamp','last_order_at','first_order_at'])
#in order to apply the cleaning function and remove characters we convert the column to string

print("Columns present in the data: ",[i for i in df.columns])
print("Number of data points: ",df.shape[0])
df.head()
# Out:
# Columns present in the data:  ['customer_id', 'order_id', 'order_timestamp', 'item_name', 'category_name', 'item_price', 'item_quantity', 'shop_id', 'shop_is_chain', 'delivered_by_efood', 'shop_cuisine', 'is_online_payment', 'order_has_discount_coupon', 'order_from_pinata', 'geographical_region_of_user', 'shop_city', 'geographical_region_of_shop', 'food_score', 'delivery_score', 'service_score', 'last_order_at', 'first_order_at']
# Number of data points:  1448011
#                         customer_id                          order_id  \
# 0  ffa59d28b6c38f291755acc2777e4fec  294c1055f6764a565f52c98b23b6f877
# 1  b878ec7fc5e19df3e8511c02212314dd  102884ef509e62864e4cf1e84327d38e
# 2  b878ec7fc5e19df3e8511c02212314dd  102884ef509e62864e4cf1e84327d38e
# 3  08665491d12f6cf4477eddc3afc9ea04  dcea001be354306c6fd6591863cb6327
# 4  08665491d12f6cf4477eddc3afc9ea04  dcea001be354306c6fd6591863cb6327
#
#             order_timestamp                          item_name  \
# 0 2021-05-23 00:29:35+00:00          ποικιλία κρεάτων 2 ατόμων
# 1 2021-05-06 14:24:08+00:00  κοτόπουλο παϊδάκια σχάρας το κιλό
# 2 2021-05-06 14:24:08+00:00  φιλετίνια κοτόπουλου πανέ ατομική
# 3 2021-05-11 19:14:39+00:00            γύρος κοτόπουλο σε πίτα
# 4 2021-05-11 19:14:39+00:00            γύρος κοτόπουλο σε πίτα
#
#               category_name  item_price  item_quantity  \
# 0          Μερίδες της ώρας       17.00              1
# 1                Με το κιλό        4.95              1
# 2  Φρέσκες σαλάτες ατομικές        3.10              1
# 3                   Τυλιχτά        2.50              1
# 4                   Τυλιχτά        2.50              1
#
#                             shop_id  shop_is_chain  delivered_by_efood  ...  \
# 0  b53467be0eb3414b91f31b7d7ba419ff          False               False  ...
# 1  84d9ee44e457ddef7f2c4f25dc8fa865           True               False  ...
# 2  84d9ee44e457ddef7f2c4f25dc8fa865           True               False  ...
# 3  059ba4b62a266b78c6988528f4ef891c          False               False  ...
# 4  059ba4b62a266b78c6988528f4ef891c          False               False  ...
#
#   order_has_discount_coupon  order_from_pinata  geographical_region_of_user  \
# 0                     False              False                       Λάρισα
# 1                     False              False                        Αθήνα
# 2                     False              False                        Αθήνα
# 3                     False              False                        Αθήνα
# 4                     False              False                        Αθήνα
#
#    shop_city geographical_region_of_shop food_score delivery_score  \
# 0     Λάρισα                      Λάρισα        NaN            NaN
# 1      Αθήνα              Μαρούσι-Δυτικά        NaN            NaN
# 2      Αθήνα              Μαρούσι-Δυτικά        NaN            NaN
# 3      Αθήνα          Αθήνα-Κάτω Πατήσια        NaN            NaN
# 4      Αθήνα          Αθήνα-Κάτω Πατήσια        NaN            NaN
#
#    service_score  last_order_at  first_order_at
# 0            NaN     2021-05-30      2018-12-01
# 1            NaN     2021-05-24      2016-02-26
# 2            NaN     2021-05-24      2016-02-26
# 3            NaN     2021-05-25      2018-10-22
# 4            NaN     2021-05-25      2018-10-22
#
# [5 rows x 22 columns]

# %%
#convert type of features to str in order to use the text_cleaning function which is comprised of the re.sub method mostly
df.geographical_region_of_shop=df.geographical_region_of_shop.astype(str)
df.geographical_region_of_user=df.geographical_region_of_user.astype(str)
df.shop_city=df.shop_city.astype(str)

# %%
# #replace "nan" with empty string, because it does not appear as null otherwise,then assign Nan to empty strings
# df['geographical_region_of_shop'] = df['geographical_region_of_shop'].replace(['nan'], '')
# df.geographical_region_of_shop = df.geographical_region_of_shop.replace(r'^\s*$', np.nan, regex=True)

# %%
# #if a value is missing in the geographical region of user column replace in with the value from shop city column
# df.geographical_region_of_ahop=df.geographical_region_of_shop.fillna(df.shop_city, inplace=True)

# %%
df[df.geographical_region_of_shop=='nan']
# Out:
# Empty DataFrame
# Columns: [customer_id, order_id, order_timestamp, item_name, category_name, item_price, item_quantity, shop_id, shop_is_chain, delivered_by_efood, shop_cuisine, is_online_payment, order_has_discount_coupon, order_from_pinata, geographical_region_of_user, shop_city, geographical_region_of_shop, food_score, delivery_score, service_score, last_order_at, first_order_at]
# Index: []
#
# [0 rows x 22 columns]

# %%
# def text_cleaning(text):
  
#   # # make all characters lowercase
#   # text = text.lower()

#   # removing character 
#   text = text.replace("-"," ") 

#   # removing Punctation
#   text = re.sub('[%s]*' % string.punctuation, '',text)

#   # removing numbers
#   text = re.sub('[0-9]+','', text)
#   #text=re.sub("[^A-Za-z]","",text)
 
#   # removing big spaces
#   text = re.sub('  +', ' ', text) 
#   #return unidecode.unidecode(text.decode('utf-8'))
  
#   return(text)

# %%
# df['geographical_region_of_shop'] = df['geographical_region_of_shop'].apply(text_cleaning)
# df['geographical_region_of_user'] = df['geographical_region_of_user'].apply(text_cleaning)
# df['shop_city'] = df['shop_city'].apply(text_cleaning)

# %%
# loop through each row of the DataFrame and apply unidecode to the city_name column
# for index, row in df.iterrows():
#     df.at[index, 'shop_city'] = unidecode(row['shop_city'])

# %% [markdown]
# # Create new features on customer level

# %% [markdown]
# ## Convert the T/F columns to 0/1

# %%
# Replacing columns with f/t to 0/1 in order to use the clustering models
#df = df.replace({"False": 0, "True": 1})
df["shop_is_chain"] = df["shop_is_chain"].astype(int)
df["order_has_discount_coupon"] = df["order_has_discount_coupon"].astype(int)
df["is_online_payment"] = df["is_online_payment"].astype(int)
df["delivered_by_efood"] = df["delivered_by_efood"].astype(int)
df["order_from_pinata"] = df["order_from_pinata"].astype(int)

# %% [markdown]
# ## Extract specific info about the order from order_timestamp feature

# %%
# Creating new features from the datetime column order_timestamp
df["year"]  = df["order_timestamp"].apply(lambda x: x.year)
df['month'] = df['order_timestamp'].apply(lambda x: x.month_name())
df['dayname'] = df['order_timestamp'].apply(lambda x: x.day_name())
df["hour"]  = df["order_timestamp"].apply(lambda x: x.hour)
df["day"]  = df["order_timestamp"].apply(lambda x: x.dayofweek)

# %% [markdown]
# ## Total value from order

# %%
df["TotalSum"] = df["item_quantity"] * df["item_price"]

# %%
# Creating a new feature 'TimeType' based on hours to define whether its Morning,Afternoon or Evening
df['part_of_the_day'] = np.where((df["hour"]>5)&(df["hour"]<18), np.where(df["hour"]<12, 'Morning','Afternoon'),'Night')

# %%
df['timestamp'] = pd.to_datetime(df['order_timestamp']).dt.date
df['last_order_at'] = pd.to_datetime(df['last_order_at']).dt.date
df['first_order_at'] = pd.to_datetime(df['first_order_at']).dt.date

# %%
# Convert to show date only
# df['timestamp']=pd.to_datetime(df['order_timestamp']).apply(lambda x: x.date())
# df['last_order_at']=pd.to_datetime(df['last_order_at']).apply(lambda x: x.date())
# df['first_order_at']=pd.to_datetime(df['first_order_at']).apply(lambda x: x.date())
# df

# %% [markdown]
# ## Snapshot day (this is the day were all calculations will be made from)

# %%
# Create date variable that records recency
import datetime
snapshot_date = max(df.timestamp) + datetime.timedelta(days=1)
snapshot_date
# Out:
# datetime.date(2021, 6, 1)

# %% [markdown]
# ## Creation of the dataframe about each customer

# %% [markdown]
# Frequency of ordering from different shops:

# %%
# group by customer_id and order_id, and calculate the number of unique order_ids and number of unique order_ids paid online
temp_customers = df.groupby('customer_id').agg(
    recency= ('last_order_at', lambda x: (snapshot_date - x.max()).days),
    monetary=('TotalSum', 'sum'),
    num_orders=('order_id', 'nunique'), 
    days_active= ('first_order_at', lambda x: (snapshot_date - x.min()).days),
    num_shops= ('shop_id', 'nunique'),
    num_items=('item_quantity', 'sum'),
    var_order_items=('item_name','nunique'),
    num_cuisines=('shop_cuisine', 'nunique'),
    categories=('category_name',lambda x: list(set(x))),
    city=('shop_city',lambda x: list(set(x))),
    region=('geographical_region_of_user',lambda x: list(set(x))),
    shop_regions=('geographical_region_of_shop',lambda x: list(set(x))),
    cuisines=('shop_cuisine',lambda x: list(set(x)))
).reset_index()

# %%
temp_customers
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories            city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...         [Αθήνα]
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...         [Αθήνα]
# 2                    [Καφέδες, Club sandwiches, Burgers]        [Κιλκίς]
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]        [Σπάρτη]
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...         [Αθήνα]
# ...                                                  ...             ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...         [Αθήνα]
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...         [Αθήνα]
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...         [Αθήνα]
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  [Πάτρα, Αθήνα]
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...         [Αθήνα]
#
#                region                                       shop_regions  \
# 0             [Αθήνα]                                       [Νέα Σμύρνη]
# 1             [Αθήνα]  [Αθήνα-Ιλίσια-Μαβίλη, Παλαιό Φάληρο, Αθήνα-Νέο...
# 2            [Κιλκίς]                                           [Κιλκίς]
# 3            [Σπάρτη]                                           [Σπάρτη]
# 4             [Αθήνα]                        [Ηλιούπολη, Αθήνα-Παγκράτι]
# ...               ...                                                ...
# 24993         [Αθήνα]  [Περιστέρι-Δυτικά, Νέα Ερυθραία-Εκάλη-Δροσιά-Δ...
# 24994         [Αθήνα]                                        [Βριλήσσια]
# 24995         [Αθήνα]                              [Πετρούπολη-Καματερό]
# 24996  [Πάτρα, Αθήνα]              [Πάτρα 2, Αθήνα-Παγκράτι, Καισαριανή]
# 24997         [Αθήνα]  [Πετρούπολη-Καματερό, Αθήνα-Ομόνοια-Πλ. Βάθης-...
#
#                                                 cuisines
# 0                                [Σουβλάκια, Μαγειρευτά]
# 1      [Σουβλάκια, Κουλούρια, Ζυμαρικά, Κρέπες, Pizza...
# 2                               [Pizza, Καφέδες, Κρέπες]
# 3                                       [Pizza, Καφέδες]
# 4      [Σουβλάκια, Κρέπες, Cocktails, Pizza, Καφέδες,...
# ...                                                  ...
# 24993  [Σουβλάκια, Βάφλες, Κρέπες, Ιταλική, Pizza, Κα...
# 24994              [Καφέδες, Κρέπες, Σουβλάκια, Burgers]
# 24995  [Σουβλάκια, Ασιατική, Καφέδες, Burgers, Ψητά -...
# 24996  [Σουβλάκια, Μαγειρευτά, Κρέπες, Pizza, Καφέδες...
# 24997               [Pizza, Καφέδες, Σουβλάκια, Burgers]
#
# [24998 rows x 14 columns]

# %% [markdown]
# ## Average info about a customer's order

# %% [markdown]
# ### Create attributes about the average value of an order, the average number of items in an order, and the averange number of categories in an order

# %%
temp_customers['avg_spent']=temp_customers['monetary'] / temp_customers['num_orders']
temp_customers['avg_items_per_order']=temp_customers['num_items'] / temp_customers['num_orders']
temp_customers['avg_num_categories_per_order']=temp_customers['categories'].apply(len)/ temp_customers['num_orders']

# %%
pct_online1 = df.groupby(['customer_id', 'order_id'])['shop_is_chain'].max().groupby('customer_id').mean().reset_index()
pct_online1.columns = ['customer_id', 'perc_chain_shops']
pct_online2 = df.groupby(['customer_id', 'order_id'])['delivered_by_efood'].max().groupby('customer_id').mean().reset_index()
pct_online2.columns = ['customer_id', 'perc_delivered_by_efood']
pct_online3 = df.groupby(['customer_id', 'order_id'])['order_has_discount_coupon'].max().groupby('customer_id').mean().reset_index()
pct_online3.columns = ['customer_id', 'perc_has_discount_coupon']
pct_online4 = df.groupby(['customer_id', 'order_id'])['is_online_payment'].max().groupby('customer_id').mean().reset_index()
pct_online4.columns = ['customer_id', 'perc_paid_online']
pct_online5 = df.groupby(['customer_id', 'order_id'])['order_from_pinata'].max().groupby('customer_id').mean().reset_index()
pct_online5.columns = ['customer_id', 'perc_from_pinata']
# merge the dataframes on customer_id
customers_df = temp_customers.merge(pct_online1, on='customer_id').merge(pct_online2, on='customer_id').merge(pct_online3, on='customer_id').merge(pct_online4, on='customer_id').merge(pct_online5, on='customer_id')
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories  ...  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...  ...
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...  ...
# 2                    [Καφέδες, Club sandwiches, Burgers]  ...
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]  ...
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...  ...
# ...                                                  ...  ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...  ...
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...  ...
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...  ...
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ...
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...  ...
#
#                                             shop_regions  \
# 0                                           [Νέα Σμύρνη]
# 1      [Αθήνα-Ιλίσια-Μαβίλη, Παλαιό Φάληρο, Αθήνα-Νέο...
# 2                                               [Κιλκίς]
# 3                                               [Σπάρτη]
# 4                            [Ηλιούπολη, Αθήνα-Παγκράτι]
# ...                                                  ...
# 24993  [Περιστέρι-Δυτικά, Νέα Ερυθραία-Εκάλη-Δροσιά-Δ...
# 24994                                        [Βριλήσσια]
# 24995                              [Πετρούπολη-Καματερό]
# 24996              [Πάτρα 2, Αθήνα-Παγκράτι, Καισαριανή]
# 24997  [Πετρούπολη-Καματερό, Αθήνα-Ομόνοια-Πλ. Βάθης-...
#
#                                                 cuisines  avg_spent  \
# 0                                [Σουβλάκια, Μαγειρευτά]  12.452941
# 1      [Σουβλάκια, Κουλούρια, Ζυμαρικά, Κρέπες, Pizza...   8.583750
# 2                               [Pizza, Καφέδες, Κρέπες]   3.369231
# 3                                       [Pizza, Καφέδες]   2.500000
# 4      [Σουβλάκια, Κρέπες, Cocktails, Pizza, Καφέδες,...   9.717021
# ...                                                  ...        ...
# 24993  [Σουβλάκια, Βάφλες, Κρέπες, Ιταλική, Pizza, Κα...  18.620833
# 24994              [Καφέδες, Κρέπες, Σουβλάκια, Burgers]  10.321875
# 24995  [Σουβλάκια, Ασιατική, Καφέδες, Burgers, Ψητά -...  16.546667
# 24996  [Σουβλάκια, Μαγειρευτά, Κρέπες, Pizza, Καφέδες...   6.680000
# 24997               [Pizza, Καφέδες, Σουβλάκια, Burgers]   7.977778
#
#       avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                4.411765                      0.705882          0.294118
# 1                2.475000                      1.050000          0.475000
# 2                1.000000                      0.230769          0.000000
# 3                1.102041                      0.081633          0.000000
# 4                2.872340                      0.787234          0.595745
# ...                   ...                           ...               ...
# 24993            3.833333                      2.500000          0.583333
# 24994            3.812500                      1.687500          0.875000
# 24995            4.200000                      1.266667          0.466667
# 24996            2.400000                      1.150000          0.700000
# 24997            1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata
# 0              0.323529
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# ...                 ...
# 24993          0.500000
# 24994          0.000000
# 24995          0.000000
# 24996          0.000000
# 24997          0.055556
#
# [24998 rows x 22 columns]

# %%
customers_df['city'] = customers_df['city'].astype(str)
customers_df['region'] = customers_df['region'].astype(str)
customers_df['cuisines'] = customers_df['cuisines'].astype(str)
customers_df['shop_regions'] = customers_df['shop_regions'].astype(str)

# %%
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories  ...  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...  ...
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...  ...
# 2                    [Καφέδες, Club sandwiches, Burgers]  ...
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]  ...
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...  ...
# ...                                                  ...  ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...  ...
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...  ...
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...  ...
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ...
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...  ...
#
#                                             shop_regions  \
# 0                                         ['Νέα Σμύρνη']
# 1      ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2                                             ['Κιλκίς']
# 3                                             ['Σπάρτη']
# 4                        ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                                                  ...
# 24993  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994                                      ['Βριλήσσια']
# 24995                            ['Πετρούπολη-Καματερό']
# 24996        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#       avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                4.411765                      0.705882          0.294118
# 1                2.475000                      1.050000          0.475000
# 2                1.000000                      0.230769          0.000000
# 3                1.102041                      0.081633          0.000000
# 4                2.872340                      0.787234          0.595745
# ...                   ...                           ...               ...
# 24993            3.833333                      2.500000          0.583333
# 24994            3.812500                      1.687500          0.875000
# 24995            4.200000                      1.266667          0.466667
# 24996            2.400000                      1.150000          0.700000
# 24997            1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata
# 0              0.323529
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# ...                 ...
# 24993          0.500000
# 24994          0.000000
# 24995          0.000000
# 24996          0.000000
# 24997          0.055556
#
# [24998 rows x 22 columns]

# %% [markdown]
# ## Frequency of orders

# %% [markdown]
# ###Which customers order every week ?

# %%
df['week'] = df['order_timestamp'].dt.week
orders_per_week = df.groupby(['customer_id', 'week'])['order_id'].count().reset_index()
weeks_per_customer = orders_per_week.groupby('customer_id')['week'].nunique().reset_index()
weeks_per_customer['orders_every_week'] = weeks_per_customer['week'] == weeks_per_customer['week'].max()
customers_df = customers_df.merge(weeks_per_customer, on='customer_id')
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories  ...  avg_spent  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...  ...  12.452941
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...  ...   8.583750
# 2                    [Καφέδες, Club sandwiches, Burgers]  ...   3.369231
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]  ...   2.500000
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...  ...   9.717021
# ...                                                  ...  ...        ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...  ...  18.620833
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...  ...  10.321875
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...  ...  16.546667
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ...   6.680000
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...  ...   7.977778
#
#       avg_items_per_order avg_num_categories_per_order perc_chain_shops  \
# 0                4.411765                     0.705882         0.294118
# 1                2.475000                     1.050000         0.475000
# 2                1.000000                     0.230769         0.000000
# 3                1.102041                     0.081633         0.000000
# 4                2.872340                     0.787234         0.595745
# ...                   ...                          ...              ...
# 24993            3.833333                     2.500000         0.583333
# 24994            3.812500                     1.687500         0.875000
# 24995            4.200000                     1.266667         0.466667
# 24996            2.400000                     1.150000         0.700000
# 24997            1.555556                     0.555556         0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  week  orders_every_week
# 0              0.323529    10               True
# 1              0.000000     9              False
# 2              0.000000     7              False
# 3              0.000000     9              False
# 4              0.000000     9              False
# ...                 ...   ...                ...
# 24993          0.500000     7              False
# 24994          0.000000     7              False
# 24995          0.000000     8              False
# 24996          0.000000     8              False
# 24997          0.055556     8              False
#
# [24998 rows x 24 columns]

# %% [markdown]
# ## Part of the day

# %% [markdown]
# ### What part of the day do the customers order most from?
# Three columns of the percentage of orders placed during morning,afternoon or nighttime.

# %%
orders_per_customer = df.groupby(['customer_id', 'part_of_the_day'])['order_id'].nunique().reset_index()
total_orders_per_customer = df.groupby('customer_id')['order_id'].nunique().reset_index()
total_orders_per_customer = total_orders_per_customer.rename(columns={'order_id': 'total_orders'})

orders_per_customer = pd.merge(orders_per_customer, total_orders_per_customer, on='customer_id')

orders_per_customer['morning_percentage'] = orders_per_customer.apply(lambda x: x['order_id'] / x['total_orders'] if x['part_of_the_day'] == 'Morning' else 0, axis=1)
orders_per_customer['afternoon_percentage'] = orders_per_customer.apply(lambda x: x['order_id'] / x['total_orders'] if x['part_of_the_day'] == 'Afternoon' else 0, axis=1)
orders_per_customer['night_percentage'] = orders_per_customer.apply(lambda x: x['order_id'] / x['total_orders'] if x['part_of_the_day'] == 'Night' else 0, axis=1)

time_period = orders_per_customer.groupby('customer_id').agg(
    morning_perc=('morning_percentage', 'sum'),
    afternoon_perc=('afternoon_percentage', 'sum'),
    night_perc= ('night_percentage', 'sum')).reset_index()
customers_df = pd.merge(customers_df, time_period, on='customer_id')
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories  ...  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...  ...
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...  ...
# 2                    [Καφέδες, Club sandwiches, Burgers]  ...
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]  ...
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...  ...
# ...                                                  ...  ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...  ...
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...  ...
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...  ...
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ...
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...  ...
#
#       perc_chain_shops perc_delivered_by_efood perc_has_discount_coupon  \
# 0             0.294118                0.000000                      0.0
# 1             0.475000                0.150000                      0.0
# 2             0.000000                0.000000                      0.0
# 3             0.000000                0.000000                      0.0
# 4             0.595745                0.000000                      0.0
# ...                ...                     ...                      ...
# 24993         0.583333                0.166667                      0.0
# 24994         0.875000                0.062500                      0.0
# 24995         0.466667                0.000000                      0.0
# 24996         0.700000                0.000000                      0.0
# 24997         0.111111                0.000000                      0.0
#
#       perc_paid_online  perc_from_pinata  week  orders_every_week  \
# 0             0.000000          0.323529    10               True
# 1             0.625000          0.000000     9              False
# 2             0.923077          0.000000     7              False
# 3             0.000000          0.000000     9              False
# 4             0.574468          0.000000     9              False
# ...                ...               ...   ...                ...
# 24993         0.583333          0.500000     7              False
# 24994         0.250000          0.000000     7              False
# 24995         0.866667          0.000000     8              False
# 24996         0.400000          0.000000     8              False
# 24997         0.888889          0.055556     8              False
#
#        morning_perc  afternoon_perc  night_perc
# 0          0.000000        0.058824    0.941176
# 1          0.250000        0.450000    0.300000
# 2          0.384615        0.153846    0.461538
# 3          0.836735        0.163265    0.000000
# 4          0.021277        0.212766    0.765957
# ...             ...             ...         ...
# 24993      0.166667        0.250000    0.583333
# 24994      0.000000        0.500000    0.500000
# 24995      0.000000        0.000000    1.000000
# 24996      0.100000        0.350000    0.550000
# 24997      0.555556        0.166667    0.277778
#
# [24998 rows x 27 columns]

# %%
pd.set_option('display.max_columns', None)
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  week  orders_every_week  morning_perc  \
# 0              0.323529    10               True      0.000000
# 1              0.000000     9              False      0.250000
# 2              0.000000     7              False      0.384615
# 3              0.000000     9              False      0.836735
# 4              0.000000     9              False      0.021277
# ...                 ...   ...                ...           ...
# 24993          0.500000     7              False      0.166667
# 24994          0.000000     7              False      0.000000
# 24995          0.000000     8              False      0.000000
# 24996          0.000000     8              False      0.100000
# 24997          0.055556     8              False      0.555556
#
#        afternoon_perc  night_perc
# 0            0.058824    0.941176
# 1            0.450000    0.300000
# 2            0.153846    0.461538
# 3            0.163265    0.000000
# 4            0.212766    0.765957
# ...               ...         ...
# 24993        0.250000    0.583333
# 24994        0.500000    0.500000
# 24995        0.000000    1.000000
# 24996        0.350000    0.550000
# 24997        0.166667    0.277778
#
# [24998 rows x 27 columns]

# %% [markdown]
# Interesting finding about coffee!

# %%
# Define the word to search for
search_word = 'Καφέδες'

# Define a lambda function to check if the word is in any of the lists in the column
contains_word = lambda row: search_word in row

# %% [markdown]
# Customers that order every day (they are only 73 out of almost 25000 so it was decided not to use this column!

# %%
# Convert the order_date column to a datetime object and extract the date component
# df['order_date'] = pd.to_datetime(df['order_timestamp']).dt.date

# # Group the dataframe by customer_id to get the number of unique order dates for each customer
# grouped_df = df.groupby('customer_id')['order_date'].nunique().reset_index(name='num_order_dates')

# # Get the set of all order dates in the dataframe
# all_dates = set(df['order_date'].unique())

# # Filter the grouped_df to include only the customers who have ordered every day
# customers_ordered_every_day = grouped_df['num_order_dates'] == len(all_dates)
# customers_ordered_every_day
# # # Join the customers_ordered_every_day series with the original df to add a boolean column
# # df = df.merge(customers_ordered_every_day, on='customer_id')
# # df['ordered_every_day'] = df['num_order_dates_y'] == len(all_dates)
# # df.drop(['num_order_dates_y'], axis=

# %% [markdown]
# ## Frequency of orders study

# %% [markdown]
# ###Which customers order at least 3 days per week ?

# %%
# Convert the order_date column to a datetime object and extract the weekday and weekofyear components
df['weekday'] = pd.to_datetime(df['order_timestamp']).dt.weekday
df['weekofyear'] = pd.to_datetime(df['order_timestamp']).dt.weekofyear
# Group the dataframe by customer_id and weekofyear to get the count of orders for each week for each customer
grouped_df = df.groupby(['customer_id', 'weekofyear'])['weekday'].nunique().reset_index(name='num_weekdays')
# Filter the grouped_df to include only the customers who have ordered at least 3 days per week every week
customers_ordered_3_days = grouped_df.groupby('customer_id')['num_weekdays'].apply(lambda x: (x >= 3).all())
# Join the customers_ordered_3_days series with the original df to add a boolean column
customers_df = customers_df.merge(customers_ordered_3_days, on='customer_id')
# Join the customers_ordered_3_days series with the original df to add a boolean column
customers_df['ordered_3_days_every_week'] = customers_df['num_weekdays']

# Join the customers_ordered_3_days series with the original df to add a boolean column
customers_df.drop(['week', 'num_weekdays'], axis=1, inplace=True)
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week
# 0        0.941176                      False
# 1        0.300000                      False
# 2        0.461538                      False
# 3        0.000000                      False
# 4        0.765957                      False
# ...           ...                        ...
# 24993    0.583333                      False
# 24994    0.500000                      False
# 24995    1.000000                      False
# 24996    0.550000                      False
# 24997    0.277778                      False
#
# [24998 rows x 27 columns]

# %% [markdown]
# ## Food, Delivery and Service Score Attributes

# %%
# Create a new column in the orders dataframe indicating whether the customer left a review or not in any of the three score columns
df['left_review'] = df[['food_score', 'delivery_score', 'service_score']].notnull().any(axis=1)

# %%
df["left_review"] = df["left_review"].astype(int)

# %% [markdown]
# ### Label customers based on whether they leave a review or not

# %%
reviews=df[df['left_review'] == 1].groupby(['customer_id', 'order_id']).size().groupby('customer_id').size().reset_index(name='scores_count')
# Join the review_count series with the original df to add the review count column

# Merge the two DataFrames using a left join and replace any missing values with 0
customers_df = customers_df.merge(reviews, on='customer_id', how='left').fillna(0)
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week  scores_count
# 0        0.941176                      False           0.0
# 1        0.300000                      False           0.0
# 2        0.461538                      False           0.0
# 3        0.000000                      False           0.0
# 4        0.765957                      False           0.0
# ...           ...                        ...           ...
# 24993    0.583333                      False           0.0
# 24994    0.500000                      False           0.0
# 24995    1.000000                      False           0.0
# 24996    0.550000                      False           0.0
# 24997    0.277778                      False           0.0
#
# [24998 rows x 28 columns]

# %%
# Create a new DataFrame with customer ID, order count, and review count
#customers_df.rename(columns={'order_id': 'Order Count', 'review_column': 'Review Count'}, inplace=True)

# Define a function to assign labels based on review ratio
def review_labels(row):
    if row['scores_count'] == 0:
        return 'Mystery Maven'
    elif row['num_orders'] == 0:
        return 'No Orders'
    elif row['scores_count'] / row['num_orders'] <= 0.25:
        return 'Silent Shopper'
    elif row['scores_count'] / row['num_orders'] <= 0.5:
        return 'Occasional'
    elif row['scores_count'] / row['num_orders'] <= 0.75:
        return 'Feedback Fanatic'
    else:
        return 'Super User'

# Apply the function to create a new column with ratio labels
customers_df['leaves_reviews'] = customers_df.apply(review_labels, axis=1)

# Merge the ratio labels back to the original DataFrame
#df = pd.merge(df, customers_df[['customer_id', 'Review Ratio']], on='customer_id')

# Print the resulting DataFrame
#print(df)

# %%
customers_df.leaves_reviews.value_counts()
# Out:
# Mystery Maven       22786
# Silent Shopper       1800
# Occasional            228
# Super User             95
# Feedback Fanatic       89
# Name: leaves_reviews, dtype: int64

# %% [markdown]
# ## Day of the week order placement

# %% [markdown]
# ###How many orders are placed on weekends and how many on weekdays feature

# %%
# Create a new dataframe with binary values for each day of the week
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_dummies = pd.get_dummies(df['dayname'])
day_dummies = day_dummies.reindex(columns=days, fill_value=0)

# Concatenate the new dataframe with the original dataframe
new_df = pd.concat([df[['customer_id','order_id']], day_dummies], axis=1)
#keep unique order ids 
new_df = new_df.drop_duplicates(subset='order_id', keep='first')
# compute total number of orders
new_df['total_orders'] = new_df.iloc[:, 2:].sum(axis=1)  
#sum orders during the week
new_df['weekend_orders_pct'] = new_df[['Saturday', 'Sunday']].sum(axis=1) / new_df['total_orders']
#sum orders during the weekend
new_df['weekday_orders_pct'] = new_df.iloc[:, 2:7].sum(axis=1) / new_df['total_orders']
#group by customer id and order to get the values
result4 = new_df.groupby(['customer_id', 'order_id'])[['weekend_orders_pct', 'weekday_orders_pct']].mean()
result5 = result4.groupby('customer_id')[['weekend_orders_pct', 'weekday_orders_pct']].mean()
customers_df=customers_df.merge(result5[['weekend_orders_pct','weekday_orders_pct']],on='customer_id')

# %%
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.941176                      False           0.0  Mystery Maven
# 1        0.300000                      False           0.0  Mystery Maven
# 2        0.461538                      False           0.0  Mystery Maven
# 3        0.000000                      False           0.0  Mystery Maven
# 4        0.765957                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993    0.583333                      False           0.0  Mystery Maven
# 24994    0.500000                      False           0.0  Mystery Maven
# 24995    1.000000                      False           0.0  Mystery Maven
# 24996    0.550000                      False           0.0  Mystery Maven
# 24997    0.277778                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct
# 0                0.264706            0.735294
# 1                0.225000            0.775000
# 2                0.307692            0.692308
# 3                0.183673            0.816327
# 4                0.319149            0.680851
# ...                   ...                 ...
# 24993            0.583333            0.416667
# 24994            0.250000            0.750000
# 24995            0.533333            0.466667
# 24996            0.350000            0.650000
# 24997            0.111111            0.888889
#
# [24998 rows x 31 columns]

# %%
customers_df.avg_items_per_order.describe()
# Out:
# count    24998.000000
# mean         3.062275
# std          1.119368
# min          1.000000
# 25%          2.312500
# 50%          2.863636
# 75%          3.571429
# max         19.421053
# Name: avg_items_per_order, dtype: float64

# %%
# Explode the column to create a new row for each value in the list
exploded_df = customers_df.explode('region')

# Get the unique values in the column
unique_values = exploded_df['region'].unique()

# Print out the unique values
print(unique_values)
# Out:
# ["['Αθήνα']" "['Κιλκίς']" "['Σπάρτη']" ... "['Κως', 'Λάρισα']"
#  "['Αλεξανδρούπολη', 'Καρδίτσα']" "['Κρυονέρι', 'Σταμάτα']"]

# %% [markdown]
# ##Geographical Region of user, keeping the one that most orders were placed from

# %%
# Group by customer id and region, and count the number of orders per region
grouped2 = df.groupby(['customer_id', 'geographical_region_of_user'])['order_id'].count().reset_index()

# Sort by customer id and number of orders per region in descending order
sorted_df = grouped2.sort_values(['customer_id', 'order_id'], ascending=[True, False])

# Drop duplicate customer id rows, keeping the first row with the highest number of orders per region
unique_df = sorted_df.drop_duplicates(subset='customer_id', keep='first')

# Reset the index
unique_df = unique_df.reset_index(drop=True)

# Print the resulting dataframe
unique_df.drop(columns='order_id',inplace=True)
# Merge the two DataFrames
customers_df = customers_df.merge(unique_df, on='customer_id')
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.941176                      False           0.0  Mystery Maven
# 1        0.300000                      False           0.0  Mystery Maven
# 2        0.461538                      False           0.0  Mystery Maven
# 3        0.000000                      False           0.0  Mystery Maven
# 4        0.765957                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993    0.583333                      False           0.0  Mystery Maven
# 24994    0.500000                      False           0.0  Mystery Maven
# 24995    1.000000                      False           0.0  Mystery Maven
# 24996    0.550000                      False           0.0  Mystery Maven
# 24997    0.277778                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user
# 0                0.264706            0.735294                       Αθήνα
# 1                0.225000            0.775000                       Αθήνα
# 2                0.307692            0.692308                      Κιλκίς
# 3                0.183673            0.816327                      Σπάρτη
# 4                0.319149            0.680851                       Αθήνα
# ...                   ...                 ...                         ...
# 24993            0.583333            0.416667                       Αθήνα
# 24994            0.250000            0.750000                       Αθήνα
# 24995            0.533333            0.466667                       Αθήνα
# 24996            0.350000            0.650000                       Αθήνα
# 24997            0.111111            0.888889                       Αθήνα
#
# [24998 rows x 32 columns]

# %% [markdown]
# ## Coffee orders!

# %% [markdown]
# ###Percentage of coffee orders for each user feature

# %%
# filter for "coffee" cuisine, drop duplicates of order_id, group by customer ID, count the number of coffee orders per customer
coffee_orders = df[df['shop_cuisine'] == 'Καφέδες'].drop_duplicates(subset='order_id').groupby('customer_id').size().reset_index(name='coffee_count')

# group the data by customer ID, count the unique order IDs to get the total number of orders per customer
total_orders = df.groupby('customer_id')['order_id'].nunique().reset_index(name='total_orders')

# merge the two dataframes on customer ID, use left join to keep all customers from total_orders
merged_coffee = pd.merge(total_orders, coffee_orders, on='customer_id', how='left')

# fill NaN values with 0 for customers who did not order coffee
merged_coffee['coffee_count'] = merged_coffee['coffee_count'].fillna(0)

# calculate the percentage of orders that were coffee for each customer
merged_coffee['coffee_percentage'] = merged_coffee['coffee_count'] / merged_coffee['total_orders']

merged_coffee
# Out:
#                             customer_id  total_orders  coffee_count  \
# 0      0001496e540173a40362759ed10b3ce2            34           0.0
# 1      0003b7de618c1acfc67eac91b853b287            40          17.0
# 2      00045e9d1c96d7e2353f886704e51c88            13           9.0
# 3      000e223791e890e85938d71bee32cf5a            49           1.0
# 4      0016652ea3c3a1176dd2385e89de9ff6            47           9.0
# ...                                 ...           ...           ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7            12           3.0
# 24994  fff262fbc647360700cee69566e26989            16           5.0
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2            15           2.0
# 24996  fffacf61b056a50e5cf7173b94c939df            20          10.0
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5            18          13.0
#
#        coffee_percentage
# 0               0.000000
# 1               0.425000
# 2               0.692308
# 3               0.020408
# 4               0.191489
# ...                  ...
# 24993           0.250000
# 24994           0.312500
# 24995           0.133333
# 24996           0.500000
# 24997           0.722222
#
# [24998 rows x 4 columns]

# %%
customers_df = customers_df.merge(merged_coffee[['customer_id', 'coffee_percentage']], on='customer_id')
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.941176                      False           0.0  Mystery Maven
# 1        0.300000                      False           0.0  Mystery Maven
# 2        0.461538                      False           0.0  Mystery Maven
# 3        0.000000                      False           0.0  Mystery Maven
# 4        0.765957                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993    0.583333                      False           0.0  Mystery Maven
# 24994    0.500000                      False           0.0  Mystery Maven
# 24995    1.000000                      False           0.0  Mystery Maven
# 24996    0.550000                      False           0.0  Mystery Maven
# 24997    0.277778                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                0.264706            0.735294                       Αθήνα
# 1                0.225000            0.775000                       Αθήνα
# 2                0.307692            0.692308                      Κιλκίς
# 3                0.183673            0.816327                      Σπάρτη
# 4                0.319149            0.680851                       Αθήνα
# ...                   ...                 ...                         ...
# 24993            0.583333            0.416667                       Αθήνα
# 24994            0.250000            0.750000                       Αθήνα
# 24995            0.533333            0.466667                       Αθήνα
# 24996            0.350000            0.650000                       Αθήνα
# 24997            0.111111            0.888889                       Αθήνα
#
#        coffee_percentage
# 0               0.000000
# 1               0.425000
# 2               0.692308
# 3               0.020408
# 4               0.191489
# ...                  ...
# 24993           0.250000
# 24994           0.312500
# 24995           0.133333
# 24996           0.500000
# 24997           0.722222
#
# [24998 rows x 33 columns]

# %% [markdown]
# ###Best customer Ever!

# %%
customers_df.set_index('customer_id')
# find the customer ID with the max value in most columns
max_cols = (customers_df == customers_df.max()).sum(axis=1)
max_customer = max_cols.idxmax()
max_customer
# Out:
# 1551

# %%
customers_df[customers_df.customer_id=='c7786aa61f55a9b73edebb79126c281c']
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 19397  c7786aa61f55a9b73edebb79126c281c        2    3517.7         106
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 19397         1693         60        784              294            21
#
#                                               categories  \
# 19397  [Handmade treats, Σπιτικά αναψυκτικά, Νηστίσιμ...
#
#                        city     region  \
# 19397  ['Παιανία', 'Αθήνα']  ['Αθήνα']
#
#                                             shop_regions  \
# 19397  ['Γέρακας-Γλυκά Νερά-Ανθούσα', 'Μελίσσια-Πεντέ...
#
#                                                 cuisines  avg_spent  \
# 19397  ['Παγωτό', 'Καφέδες', 'Sushi', 'Burgers', 'Αρτ...  33.185849
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 19397             7.396226                      1.075472          0.566038
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 19397                 0.273585                       0.0          0.367925
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 19397          0.009434               True       0.09434        0.509434
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 19397    0.396226                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 19397            0.377358            0.622642                       Αθήνα
#
#        coffee_percentage
# 19397           0.169811

# %% [markdown]
# ## Quantity of different categories in an order

# %% [markdown]
# ## Percentage of orders with more than two items for each user feature

# %%
df[df.item_quantity>=2]
# Out:
#                               customer_id                          order_id  \
# 5        08665491d12f6cf4477eddc3afc9ea04  dcea001be354306c6fd6591863cb6327
# 12       ae13c51311a65fe67b4ad7ce278853e0  76cffe53374cbf27f86bf8a716f2beb4
# 13       ae13c51311a65fe67b4ad7ce278853e0  76cffe53374cbf27f86bf8a716f2beb4
# 17       d6eedc952988d63c866682f4c007e2b7  30eb384b6ebcaa4480e16dd713777ea0
# 18       d6eedc952988d63c866682f4c007e2b7  30eb384b6ebcaa4480e16dd713777ea0
# ...                                   ...                               ...
# 1447975  8735603bb9c21afcc7bb17bc8c56b96b  034a27b3a6cbb38ac2353f0a734844ba
# 1447981  f98332421ff33eed3490922adf061bb6  ca0c52c32b0bda019aea86584be79c81
# 1447998  18451c7f61608f58d414b8419b143d52  daa8252f23da43f3c5fad668cc5f96a5
# 1448004  0c0af5099932e93de2f72c4f56c153d4  be04391aa8a1143cb777e91b163b16a9
# 1448006  4e6ab3dfff3219ffbfa26b8a2231f1a5  90260a55a7310e58a9ec1e68fd93c87e
#
#                   order_timestamp                          item_name  \
# 5       2021-05-11 19:14:39+00:00         κεμπάπ χειροποίητο σε πίτα
# 12      2021-05-05 10:05:10+00:00                    freddo espresso
# 13      2021-05-05 10:05:10+00:00                         νερό 500ml
# 17      2021-05-19 21:33:57+00:00                     classic burger
# 18      2021-05-19 21:33:57+00:00                      πατάτες large
# ...                           ...                                ...
# 1447975 2021-04-16 10:51:13+00:00           κουλούρι κλασικό τραγανό
# 1447981 2021-04-21 09:33:12+00:00                    freddo espresso
# 1447998 2021-04-08 21:13:18+00:00  σουβλάκι κοτόπουλο στήθος σε πίτα
# 1448004 2021-05-18 21:06:41+00:00                 καλαμάκι κοτόπουλο
# 1448006 2021-05-31 14:11:04+00:00                μπιφτέκι μοσχαρίσιο
#
#             category_name  item_price  item_quantity  \
# 5                 Τυλιχτά         2.5              2
# 12                Καφέδες         1.8              2
# 13             Αναψυκτικά         0.5              4
# 17                Burgers         3.5              3
# 18       Πατάτες & Extras         2.7              2
# ...                   ...         ...            ...
# 1447975         Νηστίσιμα         0.5              4
# 1447981           Καφέδες         1.7              2
# 1447998           Τυλιχτά         2.4              2
# 1448004           Τεμάχια         1.3              3
# 1448006           Τεμάχια         1.8              2
#
#                                   shop_id  shop_is_chain  delivered_by_efood  \
# 5        059ba4b62a266b78c6988528f4ef891c              0                   0
# 12       2f38b3925d4db2a311576540bee25572              1                   0
# 13       2f38b3925d4db2a311576540bee25572              1                   0
# 17       d4177b29bcb2471a8713b689816697a8              1                   1
# 18       d4177b29bcb2471a8713b689816697a8              1                   1
# ...                                   ...            ...                 ...
# 1447975  20d0b1fd7526283e64f20330d630afa0              1                   0
# 1447981  b437fbb92af66ac8602316a292b734a3              1                   0
# 1447998  f83e99491ed8d07cff6845504129d5bd              0                   0
# 1448004  f8737dfde6b0fac9e83b0b64652e2376              0                   0
# 1448006  cdbca39d5affb98cb346d0a09cbf75d2              1                   0
#
#         shop_cuisine  is_online_payment  order_has_discount_coupon  \
# 5          Σουβλάκια                  1                          0
# 12           Καφέδες                  1                          0
# 13           Καφέδες                  1                          0
# 17           Burgers                  0                          0
# 18           Burgers                  0                          0
# ...              ...                ...                        ...
# 1447975    Κουλούρια                  0                          0
# 1447981      Καφέδες                  1                          0
# 1447998    Σουβλάκια                  0                          0
# 1448004    Σουβλάκια                  0                          0
# 1448006    Σουβλάκια                  1                          0
#
#          order_from_pinata geographical_region_of_user    shop_city  \
# 5                        0                       Αθήνα        Αθήνα
# 12                       0                    Πειραιάς        Αθήνα
# 13                       0                    Πειραιάς        Αθήνα
# 17                       0                       Αθήνα        Αθήνα
# 18                       0                       Αθήνα        Αθήνα
# ...                    ...                         ...          ...
# 1447975                  0                       Αθήνα        Αθήνα
# 1447981                  0                 Θεσσαλονίκη  Θεσσαλονίκη
# 1447998                  0                       Πάτρα        Πάτρα
# 1448004                  0                       Πάτρα        Πάτρα
# 1448006                  0                       Αθήνα        Αθήνα
#
#          geographical_region_of_shop  food_score  delivery_score  \
# 5                 Αθήνα-Κάτω Πατήσια         NaN             NaN
# 12         Πειραιάς-Καμίνια-Κοκκινιά         NaN             NaN
# 13         Πειραιάς-Καμίνια-Κοκκινιά         NaN             NaN
# 17                          Ηράκλειο         NaN             NaN
# 18                          Ηράκλειο         NaN             NaN
# ...                              ...         ...             ...
# 1447975                        Ίλιον         NaN             NaN
# 1447981  Θεσσαλονίκη-Πυλαία-Πανόραμα         NaN             NaN
# 1447998                      Πάτρα 2         NaN             NaN
# 1448004                      Πάτρα 1         5.0             5.0
# 1448006                       Άλιμος         NaN             NaN
#
#          service_score last_order_at first_order_at  year  month    dayname  \
# 5                  NaN    2021-05-25     2018-10-22  2021    May    Tuesday
# 12                 NaN    2021-05-30     2020-03-03  2021    May  Wednesday
# 13                 NaN    2021-05-30     2020-03-03  2021    May  Wednesday
# 17                 NaN    2021-05-27     2016-01-24  2021    May  Wednesday
# 18                 NaN    2021-05-27     2016-01-24  2021    May  Wednesday
# ...                ...           ...            ...   ...    ...        ...
# 1447975            NaN    2021-05-23     2020-12-24  2021  April     Friday
# 1447981            NaN    2021-05-29     2016-05-17  2021  April  Wednesday
# 1447998            NaN    2021-05-27     2016-01-21  2021  April   Thursday
# 1448004            5.0    2021-05-30     2016-02-06  2021    May    Tuesday
# 1448006            NaN    2021-05-25     2016-01-09  2021    May     Monday
#
#          hour  day  TotalSum part_of_the_day   timestamp  week  weekday  \
# 5          19    1       5.0           Night  2021-05-11    19        1
# 12         10    2       3.6         Morning  2021-05-05    18        2
# 13         10    2       2.0         Morning  2021-05-05    18        2
# 17         21    2      10.5           Night  2021-05-19    20        2
# 18         21    2       5.4           Night  2021-05-19    20        2
# ...       ...  ...       ...             ...         ...   ...      ...
# 1447975    10    4       2.0         Morning  2021-04-16    15        4
# 1447981     9    2       3.4         Morning  2021-04-21    16        2
# 1447998    21    3       4.8           Night  2021-04-08    14        3
# 1448004    21    1       3.9           Night  2021-05-18    20        1
# 1448006    14    0       3.6       Afternoon  2021-05-31    22        0
#
#          weekofyear  left_review
# 5                19            0
# 12               18            0
# 13               18            0
# 17               20            0
# 18               20            0
# ...             ...          ...
# 1447975          15            0
# 1447981          16            0
# 1447998          14            0
# 1448004          20            1
# 1448006          22            0
#
# [183610 rows x 34 columns]

# %%
# group by customer_id and apply a lambda function to count the number of times
# item_quantity >= 1 for each customer
quantity_more_than_2 =df.groupby('customer_id')['item_quantity'].apply(lambda x: (x >= 2).sum()).reset_index(name='count')

customers_df['percentage_with_more_than_2']=quantity_more_than_2['count']/customers_df['num_orders']
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.941176                      False           0.0  Mystery Maven
# 1        0.300000                      False           0.0  Mystery Maven
# 2        0.461538                      False           0.0  Mystery Maven
# 3        0.000000                      False           0.0  Mystery Maven
# 4        0.765957                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993    0.583333                      False           0.0  Mystery Maven
# 24994    0.500000                      False           0.0  Mystery Maven
# 24995    1.000000                      False           0.0  Mystery Maven
# 24996    0.550000                      False           0.0  Mystery Maven
# 24997    0.277778                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                0.264706            0.735294                       Αθήνα
# 1                0.225000            0.775000                       Αθήνα
# 2                0.307692            0.692308                      Κιλκίς
# 3                0.183673            0.816327                      Σπάρτη
# 4                0.319149            0.680851                       Αθήνα
# ...                   ...                 ...                         ...
# 24993            0.583333            0.416667                       Αθήνα
# 24994            0.250000            0.750000                       Αθήνα
# 24995            0.533333            0.466667                       Αθήνα
# 24996            0.350000            0.650000                       Αθήνα
# 24997            0.111111            0.888889                       Αθήνα
#
#        coffee_percentage  percentage_with_more_than_2
# 0               0.000000                     0.382353
# 1               0.425000                     0.175000
# 2               0.692308                     0.000000
# 3               0.020408                     0.000000
# 4               0.191489                     0.234043
# ...                  ...                          ...
# 24993           0.250000                     0.166667
# 24994           0.312500                     0.125000
# 24995           0.133333                     0.400000
# 24996           0.500000                     0.000000
# 24997           0.722222                     0.055556
#
# [24998 rows x 34 columns]

# %% [markdown]
# ## GDP per Capital Data

# %%
elstat = pd.read_excel(r'/content/drive/MyDrive/GDP_PER_CAPITA.xlsx', sheet_name='Sheet1')
gdp_info = pd.DataFrame(elstat, columns=['Περιφέρειες και νομοί','2020*','Regions'])
gdp_info=gdp_info[~gdp_info['Περιφέρειες και νομοί'].str.isupper()].reset_index(drop=True)

# %%
# Round column A to the nearest integer
gdp_info['GDP'] = gdp_info['2020*'].round(0)
gdp_info['prefecture'] = gdp_info['Περιφέρειες και νομοί']
gdp_info.drop(columns=['2020*','Περιφέρειες και νομοί'], inplace=True)

# %%
# split comma-separated values in column prefecture and create new rows
# pd.set_option('display.max_rows', 87)

gdp_info = gdp_info.assign(prefecture=gdp_info['prefecture'].str.split(',')).explode('prefecture').reset_index(drop=True)
gdp_info['prefecture'] = gdp_info['prefecture'].str.strip()

# %%
gdp_info
# Out:
#                      Regions      GDP               prefecture
# 0                     Attiki  21134.0                   Αττική
# 1     Voreios Tomeas Athinon  25665.0    Βόρειος Τομέας Αθηνών
# 2     Dytikos Tomeas Athinon  10608.0    Δυτικός Τομέας Αθηνών
# 3   Kentrikos Tomeas Athinon  30454.0  Κεντρικός Τομέας Αθηνών
# 4      Notios Tomeas Athinon  18127.0     Νότιος Τομέας Αθηνών
# ..                       ...      ...                      ...
# 82                  Argolida  14408.0                 Αργολίδα
# 83                   Arkadia  17931.0                  Αρκαδία
# 84                 Korinthia  13212.0                 Κορινθία
# 85                   Lakonia  11864.0                  Λακωνία
# 86                  Messinia  11724.0                 Μεσσηνία
#
# [87 rows x 3 columns]

# %%
# Group orders by customer and location and count the number of orders
df3 = df.groupby(['customer_id', 'geographical_region_of_shop']).agg({'order_id': 'count'}).reset_index()

# Sort by count and drop duplicates to keep only the location with the highest count for each customer
max_orders = df3.sort_values('order_id', ascending=False).drop_duplicates('customer_id').reset_index(drop=True)

# Print the resulting dataframe
max_orders
# Out:
#                             customer_id          geographical_region_of_shop  \
# 0      a702193e88fbcd649e6eec90d67d5a06                              Χαλκίδα
# 1      a3b494cede85bc23a1d0551bf8a11ada                     Χολαργός-Παπάγου
# 2      2c524856cc61e2d59dbbd41c453fbe1c                               Νίκαια
# 3      2d1d18d506ff73f0dc94d240fab0815f          Αθήνα-Εξάρχεια-Πανεπιστήμιο
# 4      dce41e4eb4a3dd31c0e526da4b1b3474                                Βόλος
# ...                                 ...                                  ...
# 24993  62e1b3685498018c6367afce605aa701                                  Κώς
# 24994  17932beb378abff1ee75a93e70950024                            Κερατσίνι
# 24995  2061b4ac8aa46c364e81567b3808df9d                 Θεσσαλονίκη-Άνω Πόλη
# 24996  25064a84704ce206447b6a94c03d9da9  Αθήνα-Ομόνοια-Πλ. Βάθης-Στ. Λαρίσης
# 24997  8fe251d7f6d28e9f65f9c980fc3d409e                           Κορυδαλλός
#
#        order_id
# 0           557
# 1           435
# 2           423
# 3           382
# 4           371
# ...         ...
# 24993         5
# 24994         4
# 24995         3
# 24996         3
# 24997         2
#
# [24998 rows x 3 columns]

# %%
max_orders['geographical_region_of_shop'] = max_orders['geographical_region_of_shop'].str.strip()

# %%
max_orders
# Out:
#                             customer_id          geographical_region_of_shop  \
# 0      a702193e88fbcd649e6eec90d67d5a06                              Χαλκίδα
# 1      a3b494cede85bc23a1d0551bf8a11ada                     Χολαργός-Παπάγου
# 2      2c524856cc61e2d59dbbd41c453fbe1c                               Νίκαια
# 3      2d1d18d506ff73f0dc94d240fab0815f          Αθήνα-Εξάρχεια-Πανεπιστήμιο
# 4      dce41e4eb4a3dd31c0e526da4b1b3474                                Βόλος
# ...                                 ...                                  ...
# 24993  62e1b3685498018c6367afce605aa701                                  Κώς
# 24994  17932beb378abff1ee75a93e70950024                            Κερατσίνι
# 24995  2061b4ac8aa46c364e81567b3808df9d                 Θεσσαλονίκη-Άνω Πόλη
# 24996  25064a84704ce206447b6a94c03d9da9  Αθήνα-Ομόνοια-Πλ. Βάθης-Στ. Λαρίσης
# 24997  8fe251d7f6d28e9f65f9c980fc3d409e                           Κορυδαλλός
#
#        order_id
# 0           557
# 1           435
# 2           423
# 3           382
# 4           371
# ...         ...
# 24993         5
# 24994         4
# 24995         3
# 24996         3
# 24997         2
#
# [24998 rows x 3 columns]

# %% [markdown]
# ## Create dictionary with cities

# %%
pref_dict = {
    'Δυτικός Τομέας Αθηνών': ['Αγία Βαρβάρα','Αθήνα-Σεπόλια','Αθήνα-Κολωνός','Πετρούπολη-Καματερό','Αιγάλεω-Ανατολικά','Αιγάλεω-Δυτικά','Ίλιον','Περιστέρι-Ανατολικά', 'Περιστέρι-Δυτικά','Άγιοι Ανάργυροι', 'Χαϊδάρι-Σκαραμαγκάς','Περιστέρι','Πετρούπολη','Χαιδάρι-Σκαραμαγκάς','Αγία Βαρβάρα','Σκαραμαγκάς','Χαϊδαρίου'],
    'Κεντρικός Τομέας Αθηνών': ['Αθήνα','Υμηττός','Αθήνα-Ομόνοια-Πλ. Βάθης-Στ. Λαρίσης','Νέα Χαλκηδόνα','Αθήνα-Βικτώρια-Πλ. Αττικής','Αθήνα-Σύνταγμα-Πλάκα','Ταύρος','Αθήνα-Ρούφ-Βοτανικός','Νέα Φιλαδέλφεια','Αθήνα-Πατήσια-Πλατεία Αμερικής','Αθήνα-Κολωνάκι','Αθήνα-Θησείο-Ψυρρή-Μεταξουργείο','Αθήνα-Κουκάκι','Αθήνα-Ιλίσια-Μαβίλη','Δάφνη','Αθήνα-Πετράλωνα','Αθήνα-Εξάρχεια-Πανεπιστήμιο','Καισαριανή','Αθήνα-Νεάπολη-Λυκαβηττός','Αθήνα-Αμπελόκηποι-Μιχαλακοπούλου-Κατεχάκη','Αθήνα-Αμπελόκηποι-Πανόρμου','Αθήνα-Κάτω Πατήσια','Βύρωνας','Αθήνα-Άνω Πατήσια','Ζωγράφου','Αθήνα-Κυψέλη','Αθήνα-Νέος Κόσμος','Αθήνα-Παγκράτι'],
    'Βόρειος Τομέας Αθηνών': ['Νέα Ιωνία','Κηφισιά-Κεφαλάρι-Πολιτεία','Μεταμόρφωση','Λυκόβρυση-Πεύκη','Αθήνα-Γκύζη-Νέα Φιλοθέη','Ηράκλειο','Μαρούσι-Δυτικά','Γαλάτσι','Αγία Παρασκευή','Κηφισιά-Άνω', 'Μελίσσια', 'Νέο Ψυχικό', 'Πεντέλη','Νέα Ερυθραία-Εκάλη-Δροσιά-Διόνυσος','Νέο Ψυχικό-Πεντάγωνο','Μελίσσια-Πεντέλη','Βριλήσσια', 'Χολαργός-Παπάγου','Χαλάνδρι-Πολύδροσο', 'Χαλάνδρι-Κάτω', 'Κηφισιά-Κάτω','Μαρούσι-Ανατολικά','Μεταμόρφωση'],
    'Ανατολική Αττική': ['Ανάβυσσος','Αρτέμιδα','Λαγονήσι','Ψυχικό-Φιλοθέη','Σταμάτα-Κρυονέρι-Άνοιξη-Άγιος Στέφανος','Βάρη-Βουλιαγμένη','Βούλα','Γέρακας-Γλυκά Νερά-Ανθούσα','Αχαρνές','Σπάτα', 'Νέος Βουτζάς', 'Σταμάτα', 'Μαρκόπουλο', 'Καλύβια Θορικού', 'Κρυονέρι','Κερατέα','Ντράφι','Μαραθώνας','Πικέρμι','Πόρτο Ράφτη ','Σαρωνίδα','Ροδόπολη','Ανάβυσσος','Άρτεμις', 'Ραφήνα', 'Μαρκόπουλο', 'Σπάτα', 'Άνοιξη', 'Νέα Μάκρη','Άγιος Στέφανος','Δροσιά','Παλλήνη','Διόνυσος','Μάνδρα','Παιανία','Κορωπί','Θρακομακεδόνες'],
    'Δυτική Αττική': ['Άνω Λιόσια','Μαγούλα', 'Φυλή', 'Μάνδρα', 'Ελευσίνα', 'Μέγαρα','Ασπρόπυργος',' Οινόη','Άγιοι Ανάργυροι'],
    'Νότιος Τομέας Αθηνών': ['Ελληνικό','Μοσχάτο','Αργυρούπολη','Άλιμος','Άνω Γλυφάδα','Γλυφάδα','Παλαιό Φάληρο', 'Ηλιούπολη','Καλλιθέα-Δυτικά', 'Καλλιθέα-Ανατολικά', 'Νέα Σμύρνη','Άγιος Δημήτριος'],
    'Κρήτη' : ['Φαιστός','Ρέθυμνο Κρήτης','Ρέθυμνο Κρήτη','Χανιά Κρήτης', 'Χανιά Κρήτη','Σητεία Κρήτης', 'Σητεία Κρήτη','Άγιος Νικόλαος Κρήτης', 'Άγιος Νικόλαος Κρήτη','Ηράκλειο Κρήτης 1','Ηράκλειο Κρήτης 3','Ηράκλειο Κρήτης 2','Ιεράπετρα Κρήτη','Ιεράπετρα Κρήτης'],
    'Πειραιάς' : ['Νέο Φάληρο',"Άγιος Ιωάννης Ρέντης",'Πειραιάς-Κέντρο','Πειραιάς-Πειραική','Κερατσίνι','Πειραιάς','Νίκαια','Κορυδαλλός','Πειραιάς-Καμίνια-Κοκκινιά','Πειραιάς-Μανιάτικα-Αγία Σοφία-Παπαστράτειο','Πειραιάς-Καστέλλα-Πανεπιστήμιο','Πέραμα','Πειραιάς-Δραπετσώνα','Κερατσίνι','Άγιος Ιωαννης','Ρέντη'],
    'Ρόδος':['Ιαλυσός Κρεμαστή'],
    'Ημαθία':['Αλεξάνδρεια','Αλεξάνδρεια','Βέροια','Νάουσα'],
    'Θεσσαλονίκη': ['Θεσσαλονίκη-Επανομή','Θεσσαλονίκη-Λαγκαδάς','Θεσσαλονίκη-Σίνδος','Θεσσαλονίκη-Εύοσμος-Ελευθέριο-Κορδελιό-Σταυρούπολη', 'Θεσσαλονίκη-Άνω Πόλη', 'Θεσσαλονίκη-Καλαμαριά-Παλιά Παραλία', 'Θεσσαλονίκη-Τούμπα', 'Θεσσαλονίκη-Κέντρο Ανατολικά-Πανεπιστήμιο-40 Εκκλησιές', 'Θεσσαλονίκη-Κέντρο Δυτικά-Δικαστήρια-Παλιός Σταθμός-Αμπελόκηποι-Ξηροκρήνη-Μενεμένη', 'Θεσσαλονίκη-Χαριλάου-Μαρτίου-Βουλγάρη', 'Θεσσαλονίκη-Νεάπολη-Συκιές-Πολίχνη', 'Θεσσαλονίκη-Ανάληψη', 'Θεσσαλονίκη-Αγία Τριάδα-(Μακεδονία Παλλάς)', 'Θεσσαλονίκη-Κέντρο-Αγίου Δημητρίου', 'Θεσσαλονίκη-Αγία Τριάδα-(28ης Οκτωβρίου)', 'Θεσσαλονίκη-Τριανδρία-ΆνωΤούμπα', 'Θεσσαλονίκη-Πυλαία-Πανόραμα', 'Θεσσαλονίκη-Ευκαρπία-Ωραιόκαστρο', 'Θεσσαλονίκη-Περαία-Νέοι Επιβάτες-Αγία Τριάδα-Νέα Μηχανιώνα', 'Θεσσαλονίκη-Θέρμη', 
                    'Θεσσαλονίκη-Πεύκα'],
    'Κοζάνη':['Πτολεμαίδα'],
    'Νήσοι':['Πτολεμαίδα','Πόρος','Αίγινα','Σαλαμίνα','Σπέτσες'],
    'Αργολίδα':['Άργος','Ναύπλιο'],
    'Μαγνησία':['Αλμυρός','Βόλος'],
    'Αχαΐα': ['Αίγιο','Πάτρα','Πάτρα 1','Πάτρα 2','Πάτρα 3'],
    'Λακωνία': ['Σκάλα','Σπάρτη','Σπάρτη ','Γύθειο'],
    'Πέλλα':['Γιαννιτσά','Έδεσσα'],
    'Ευρυτανία':['Καρπενήσι'],
    'Πιερία':['Κατερίνη'],
   'Ηλεία':['Πύργος'],
    'Έβρος':['Ορεστιάδα','Αλεξανδρούπολη','Διδυμότειχο'],
    'Εύβοια':['Χαλκίδα','Κάρυστος'],
    'Κορινθία':['Κιάτο','Κόρινθος','Λουτράκι'],
    'Αιτωλοακαρνανία':['Μεσολόγγι','Ναύπακτος','Αγρίνιο'],
    'Μεσσηνία' :['Καλαμάτα'],
    'Ροδόπη': ['Κομοτηνή'],
    'Αρκαδία':['Τρίπολη'],
    'Φθιώτιδα':['Λαμία'],
    'Βοιωτία': ['Λιβαδειά','Θήβα'],
   'Θεσπρωτία':['Ηγουμενίτσα'],
   'Κως':['Κώς'],
   'Κεφαλληνία' : ['Κεφαλονιά'],
   'Χαλκιδική':['Χαλκιδική 1'],
   'Νότιο Αιγαίο':['Λέρος']}

# %%
# Define a function that maps cities to their respective regions
def get_region(city):
    for region, cities in pref_dict.items():
        if city in cities:
            return region
    return city

# Add a new column to the DataFrame that maps cities to regions_dict
max_orders['prefecture'] = max_orders['geographical_region_of_shop'].apply(get_region)

# Print the resulting DataFrame
max_orders
# Out:
#                             customer_id          geographical_region_of_shop  \
# 0      a702193e88fbcd649e6eec90d67d5a06                              Χαλκίδα
# 1      a3b494cede85bc23a1d0551bf8a11ada                     Χολαργός-Παπάγου
# 2      2c524856cc61e2d59dbbd41c453fbe1c                               Νίκαια
# 3      2d1d18d506ff73f0dc94d240fab0815f          Αθήνα-Εξάρχεια-Πανεπιστήμιο
# 4      dce41e4eb4a3dd31c0e526da4b1b3474                                Βόλος
# ...                                 ...                                  ...
# 24993  62e1b3685498018c6367afce605aa701                                  Κώς
# 24994  17932beb378abff1ee75a93e70950024                            Κερατσίνι
# 24995  2061b4ac8aa46c364e81567b3808df9d                 Θεσσαλονίκη-Άνω Πόλη
# 24996  25064a84704ce206447b6a94c03d9da9  Αθήνα-Ομόνοια-Πλ. Βάθης-Στ. Λαρίσης
# 24997  8fe251d7f6d28e9f65f9c980fc3d409e                           Κορυδαλλός
#
#        order_id               prefecture
# 0           557                   Εύβοια
# 1           435    Βόρειος Τομέας Αθηνών
# 2           423                 Πειραιάς
# 3           382  Κεντρικός Τομέας Αθηνών
# 4           371                 Μαγνησία
# ...         ...                      ...
# 24993         5                      Κως
# 24994         4                 Πειραιάς
# 24995         3              Θεσσαλονίκη
# 24996         3  Κεντρικός Τομέας Αθηνών
# 24997         2                 Πειραιάς
#
# [24998 rows x 4 columns]

# %%
gdp_info
# Out:
#                      Regions      GDP               prefecture
# 0                     Attiki  21134.0                   Αττική
# 1     Voreios Tomeas Athinon  25665.0    Βόρειος Τομέας Αθηνών
# 2     Dytikos Tomeas Athinon  10608.0    Δυτικός Τομέας Αθηνών
# 3   Kentrikos Tomeas Athinon  30454.0  Κεντρικός Τομέας Αθηνών
# 4      Notios Tomeas Athinon  18127.0     Νότιος Τομέας Αθηνών
# ..                       ...      ...                      ...
# 82                  Argolida  14408.0                 Αργολίδα
# 83                   Arkadia  17931.0                  Αρκαδία
# 84                 Korinthia  13212.0                 Κορινθία
# 85                   Lakonia  11864.0                  Λακωνία
# 86                  Messinia  11724.0                 Μεσσηνία
#
# [87 rows x 3 columns]

# %%
# Merge the two dataframes on the 'prefecture' column
merged_gdp = pd.merge(max_orders, gdp_info[['prefecture', 'GDP']], on='prefecture', how='left')
merged_gdp
# Out:
#                             customer_id          geographical_region_of_shop  \
# 0      a702193e88fbcd649e6eec90d67d5a06                              Χαλκίδα
# 1      a3b494cede85bc23a1d0551bf8a11ada                     Χολαργός-Παπάγου
# 2      2c524856cc61e2d59dbbd41c453fbe1c                               Νίκαια
# 3      2d1d18d506ff73f0dc94d240fab0815f          Αθήνα-Εξάρχεια-Πανεπιστήμιο
# 4      dce41e4eb4a3dd31c0e526da4b1b3474                                Βόλος
# ...                                 ...                                  ...
# 24993  62e1b3685498018c6367afce605aa701                                  Κώς
# 24994  17932beb378abff1ee75a93e70950024                            Κερατσίνι
# 24995  2061b4ac8aa46c364e81567b3808df9d                 Θεσσαλονίκη-Άνω Πόλη
# 24996  25064a84704ce206447b6a94c03d9da9  Αθήνα-Ομόνοια-Πλ. Βάθης-Στ. Λαρίσης
# 24997  8fe251d7f6d28e9f65f9c980fc3d409e                           Κορυδαλλός
#
#        order_id               prefecture      GDP
# 0           557                   Εύβοια  13415.0
# 1           435    Βόρειος Τομέας Αθηνών  25665.0
# 2           423                 Πειραιάς  18143.0
# 3           382  Κεντρικός Τομέας Αθηνών  30454.0
# 4           371                 Μαγνησία  11668.0
# ...         ...                      ...      ...
# 24993         5                      Κως  12428.0
# 24994         4                 Πειραιάς  18143.0
# 24995         3              Θεσσαλονίκη  13091.0
# 24996         3  Κεντρικός Τομέας Αθηνών  30454.0
# 24997         2                 Πειραιάς  18143.0
#
# [24998 rows x 5 columns]

# %%
pd.set_option('display.max_rows', 204)
merged_gdp.prefecture.value_counts()
# Out:
# Κεντρικός Τομέας Αθηνών    4276
# Βόρειος Τομέας Αθηνών      3097
# Νότιος Τομέας Αθηνών       3074
# Θεσσαλονίκη                2795
# Δυτικός Τομέας Αθηνών      2202
# Πειραιάς                   1909
# Κρήτη                      1254
# Ανατολική Αττική            982
# Αχαΐα                       830
# Λάρισα                      516
# Μαγνησία                    477
# Ιωάννινα                    353
# Ρόδος                       261
# Μεσσηνία                    258
# Έβρος                       256
# Ξάνθη                       228
# Καβάλα                      213
# Φθιώτιδα                    185
# Αιτωλοακαρνανία             177
# Εύβοια                      175
# Κοζάνη                      170
# Δυτική Αττική               122
# Τρίκαλα                     108
# Πιερία                      102
# Ροδόπη                       95
# Ημαθία                       86
# Δράμα                        81
# Σέρρες                       78
# Καρδίτσα                     74
# Αρκαδία                      71
# Λακωνία                      68
# Κορινθία                     61
# Κέρκυρα                      57
# Κως                          56
# Κιλκίς                       39
# Αργολίδα                     30
# Άρτα                         29
# Βοιωτία                      26
# Σύρος                        24
# Νήσοι                        18
# Πέλλα                        17
# Καστοριά                     14
# Γρεβενά                      10
# Ζάκυνθος                      9
# Ηλεία                         7
# Κεφαλληνία                    5
# Χαλκιδική                     5
# Πάρος                         3
# Μύκονος                       3
# Νότιο Αιγαίο                  3
# Σάμος                         3
# Κάλυμνος                      2
# Χίος                          1
# Ευρυτανία                     1
# Θεσπρωτία                     1
# Φλώρινα                       1
# Name: prefecture, dtype: int64

# %% [markdown]
#  ## Cencus 2021 Data

# %%
pop = pd.read_excel(r'/content/drive/MyDrive/nom_plith_2021.xlsx', sheet_name='ΝΟΜΙΜΟΣ2021')
population_df = pd.DataFrame(pop, columns=['Περιγραφή','Πληθυσμός 2021'])
# Rename the columns using a dictionary
population_df = population_df.rename(columns={'Περιγραφή': 'dimos', 'Πληθυσμός 2021': 'population'})
population_df
# Out:
#                                           dimos  population
# 0                                  ΣΥΝΟΛΟ ΧΩΡΑΣ     9716889
# 1                  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΡΟΔΟΠΗΣ      101767
# 2                               ΔΗΜΟΣ ΚΟΜΟΤΗΝΗΣ       54833
# 3                    ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΚΟΜΟΤΗΝΗΣ       48971
# 4                     ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΙΓΕΙΡΟΥ        3258
# ...                                         ...         ...
# 1441                              ΔΗΜΟΣ ΣΦΑΚΙΩΝ        3052
# 1442                   ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΣΦΑΚΙΩΝ        3052
# 1443                                 ΑΓΙΟ ΟΡΟΣ         1514
# 1444                   ΑΓΙΟ ΟΡΟΣ (ΑΥΤΟΔΙΟΙΚΗΤΟ)        1514
# 1445  ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ΑΓΙΟ ΟΡΟΣ (Αυτοδιοίκητο)        1514
#
# [1446 rows x 2 columns]

# %%
df_subset = population_df.iloc[:1] # keep first two rows
#df_subset = df_subset.append(population_df.iloc[989:1164, :])

# %%
# boolean indexing to subset DataFrame
#df_subset = population_df.append(population_df[population_df['dimos'].str.startswith('ΔΗΜΟΣ')]) # keep rows that start with 'ΔΗΜΟΣ'
df_subset = df_subset.append(population_df[population_df['dimos'].str.startswith('ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ')]).reset_index(drop=True) # keep rows that start with 'ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ'
df_subset
# Out:
#                                                 dimos  population
# 0                                        ΣΥΝΟΛΟ ΧΩΡΑΣ     9716889
# 1                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΡΟΔΟΠΗΣ      101767
# 2                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΔΡΑΜΑΣ       95701
# 3                          ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΕΒΡΟΥ      134776
# 4                          ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΘΑΣΟΥ       12815
# 5                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΑΒΑΛΑΣ      117057
# 6                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΞΑΝΘΗΣ      107548
# 7                   ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΘΕΣΣΑΛΟΝΙΚΗΣ      884945
# 8                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΗΜΑΘΙΑΣ      136602
# 9                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΙΛΚΙΣ       85885
# 10                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΠΕΛΛΑΣ      138568
# 11                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΠΙΕΡΙΑΣ      123245
# 12                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΣΕΡΡΩΝ      182226
# 13                    ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΧΑΛΚΙΔΙΚΗΣ      104702
# 14                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΟΖΑΝΗΣ      149733
# 15                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΓΡΕΒΕΝΩΝ       34548
# 16                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΑΣΤΟΡΙΑΣ       48464
# 17                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΦΛΩΡΙΝΑΣ       50921
# 18                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΙΩΑΝΝΙΝΩΝ      163044
# 19                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΡΤΑΣ       79776
# 20                    ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΘΕΣΠΡΩΤΙΑΣ       47947
# 21                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΠΡΕΒΕΖΑΣ       62769
# 22                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΛΑΡΙΣΑΣ      268451
# 23                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΑΡΔΙΤΣΑΣ      129171
# 24                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΑΓΝΗΣΙΑΣ      169831
# 25                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΣΠΟΡΑΔΩΝ       12048
# 26                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΤΡΙΚΑΛΩΝ      139562
# 27                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΦΘΙΩΤΙΔΑΣ      151036
# 28                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΒΟΙΩΤΙΑΣ      109293
# 29                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΕΥΒΟΙΑΣ      213179
# 30                    ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΕΥΡΥΤΑΝΙΑΣ       24545
# 31                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΦΩΚΙΔΑΣ       39800
# 32                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΕΡΚΥΡΑΣ       97037
# 33                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΖΑΚΥΝΘΟΥ       38340
# 34                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΙΘΑΚΗΣ        3333
# 35                   ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΕΦΑΛΛΗΝΙΑΣ       37736
# 36                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΛΕΥΚΑΔΑΣ       25365
# 37                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΧΑΪΑΣ      296574
# 38              ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ      235371
# 39                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΗΛΕΙΑΣ      168358
# 40                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΡΚΑΔΙΑΣ       96092
# 41                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΡΓΟΛΙΔΑΣ       93934
# 42                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΟΡΙΝΘΙΑΣ      136401
# 43                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΛΑΚΩΝΙΑΣ       87104
# 44                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΕΣΣΗΝΙΑΣ      161953
# 45        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΕΝΤΡΙΚΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      717373
# 46          ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΒΟΡΕΙΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      481758
# 47          ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΔΥΤΙΚΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      405623
# 48           ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΝΟΤΙΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      425112
# 49            ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ      403714
# 50               ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ      148548
# 51                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΠΕΙΡΑΙΩΣ      388480
# 52                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΝΗΣΩΝ       68917
# 53                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΛΕΣΒΟΥ       81983
# 54                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΙΚΑΡΙΑΣ       12002
# 55                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΛΗΜΝΟΥ       15841
# 56                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΣΑΜΟΥ       30200
# 57                          ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΧΙΟΥ       52096
# 58                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΣΥΡΟΥ       20371
# 59                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΑΝΔΡΟΥ       10806
# 60                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΘΗΡΑΣ       17612
# 61                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΑΛΥΜΝΟΥ       32305
# 62  ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΑΡΠΑΘΟΥ - ΗΡΩΙΚΗΣ ΝΗΣΟΥ ...        8297
# 63                 ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΕΑΣ - ΚΥΘΝΟΥ        4626
# 64                            ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΚΩ       30322
# 65                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΗΛΟΥ       11546
# 66                       ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΜΥΚΟΝΟΥ        9053
# 67                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΝΑΞΟΥ       24381
# 68                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΠΑΡΟΥ       14518
# 69                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΡΟΔΟΥ      109667
# 70                         ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΤΗΝΟΥ        9825
# 71                     ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΗΡΑΚΛΕΙΟΥ      285528
# 72                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΛΑΣΙΘΙΟΥ       73258
# 73                      ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΡΕΘΥΜΝΟΥ       79801
# 74                        ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ΧΑΝΙΩΝ      144259

# %%
# define dictionary of words to replace
replace_dict = {'ΔΗΜΟΤΙΚΗ ΕΝΟΤΗΤΑ ': '', 'ΔΗΜΟΣ ': '', 'ΠΕΡΙΦΕΡΕΙΑΚΗ ΕΝΟΤΗΤΑ ': ''}

# replace words in column using replace() method with regex=True
df_subset['dimos'] = df_subset['dimos'].replace(replace_dict, regex=True)
df_subset
# Out:
#                              dimos  population
# 0                     ΣΥΝΟΛΟ ΧΩΡΑΣ     9716889
# 1                          ΡΟΔΟΠΗΣ      101767
# 2                           ΔΡΑΜΑΣ       95701
# 3                            ΕΒΡΟΥ      134776
# 4                            ΘΑΣΟΥ       12815
# 5                          ΚΑΒΑΛΑΣ      117057
# 6                           ΞΑΝΘΗΣ      107548
# 7                     ΘΕΣΣΑΛΟΝΙΚΗΣ      884945
# 8                          ΗΜΑΘΙΑΣ      136602
# 9                           ΚΙΛΚΙΣ       85885
# 10                          ΠΕΛΛΑΣ      138568
# 11                         ΠΙΕΡΙΑΣ      123245
# 12                          ΣΕΡΡΩΝ      182226
# 13                      ΧΑΛΚΙΔΙΚΗΣ      104702
# 14                         ΚΟΖΑΝΗΣ      149733
# 15                        ΓΡΕΒΕΝΩΝ       34548
# 16                       ΚΑΣΤΟΡΙΑΣ       48464
# 17                        ΦΛΩΡΙΝΑΣ       50921
# 18                       ΙΩΑΝΝΙΝΩΝ      163044
# 19                           ΑΡΤΑΣ       79776
# 20                      ΘΕΣΠΡΩΤΙΑΣ       47947
# 21                        ΠΡΕΒΕΖΑΣ       62769
# 22                         ΛΑΡΙΣΑΣ      268451
# 23                       ΚΑΡΔΙΤΣΑΣ      129171
# 24                       ΜΑΓΝΗΣΙΑΣ      169831
# 25                        ΣΠΟΡΑΔΩΝ       12048
# 26                        ΤΡΙΚΑΛΩΝ      139562
# 27                       ΦΘΙΩΤΙΔΑΣ      151036
# 28                        ΒΟΙΩΤΙΑΣ      109293
# 29                         ΕΥΒΟΙΑΣ      213179
# 30                      ΕΥΡΥΤΑΝΙΑΣ       24545
# 31                         ΦΩΚΙΔΑΣ       39800
# 32                        ΚΕΡΚΥΡΑΣ       97037
# 33                        ΖΑΚΥΝΘΟΥ       38340
# 34                          ΙΘΑΚΗΣ        3333
# 35                     ΚΕΦΑΛΛΗΝΙΑΣ       37736
# 36                        ΛΕΥΚΑΔΑΣ       25365
# 37                          ΑΧΑΪΑΣ      296574
# 38                ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ      235371
# 39                          ΗΛΕΙΑΣ      168358
# 40                        ΑΡΚΑΔΙΑΣ       96092
# 41                       ΑΡΓΟΛΙΔΑΣ       93934
# 42                       ΚΟΡΙΝΘΙΑΣ      136401
# 43                        ΛΑΚΩΝΙΑΣ       87104
# 44                       ΜΕΣΣΗΝΙΑΣ      161953
# 45          ΚΕΝΤΡΙΚΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      717373
# 46            ΒΟΡΕΙΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      481758
# 47            ΔΥΤΙΚΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      405623
# 48             ΝΟΤΙΟΥ ΤΟΜΕΑ ΑΘΗΝΩΝ      425112
# 49              ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ      403714
# 50                 ΔΥΤΙΚΗΣ ΑΤΤΙΚΗΣ      148548
# 51                        ΠΕΙΡΑΙΩΣ      388480
# 52                           ΝΗΣΩΝ       68917
# 53                          ΛΕΣΒΟΥ       81983
# 54                         ΙΚΑΡΙΑΣ       12002
# 55                          ΛΗΜΝΟΥ       15841
# 56                           ΣΑΜΟΥ       30200
# 57                            ΧΙΟΥ       52096
# 58                           ΣΥΡΟΥ       20371
# 59                          ΑΝΔΡΟΥ       10806
# 60                           ΘΗΡΑΣ       17612
# 61                        ΚΑΛΥΜΝΟΥ       32305
# 62  ΚΑΡΠΑΘΟΥ - ΗΡΩΙΚΗΣ ΝΗΣΟΥ ΚΑΣΟΥ        8297
# 63                   ΚΕΑΣ - ΚΥΘΝΟΥ        4626
# 64                              ΚΩ       30322
# 65                           ΜΗΛΟΥ       11546
# 66                         ΜΥΚΟΝΟΥ        9053
# 67                           ΝΑΞΟΥ       24381
# 68                           ΠΑΡΟΥ       14518
# 69                           ΡΟΔΟΥ      109667
# 70                           ΤΗΝΟΥ        9825
# 71                       ΗΡΑΚΛΕΙΟΥ      285528
# 72                        ΛΑΣΙΘΙΟΥ       73258
# 73                        ΡΕΘΥΜΝΟΥ       79801
# 74                          ΧΑΝΙΩΝ      144259

# %%
# lowercase the matching columns in both dataframes
merged_gdp['prefecture'] = merged_gdp['prefecture'].str.lower()
df_subset['dimos'] = df_subset['dimos'].str.lower()
merged_gdp['geographical_region_of_shop'] = merged_gdp['geographical_region_of_shop'].str.lower()

# %%
# from google.colab import files
# df_subset.to_csv('output.csv', encoding = 'utf-8-sig') 
# files.download('output.csv')

# %% [markdown]
# Read the census dataset after a small cleaning process was done in Excel

# %%
census = pd.read_csv("/content/drive/MyDrive/output.csv",header=0)
census.drop(columns='Unnamed: 0',inplace=True)

# %% [markdown]
# Remove tabs from left and right

# %%
census['dimos'] = census['dimos'].str.strip()

# %% [markdown]
# Remove accents since the regions are in greek to make our life easier!

# %%
import unicodedata

merged_gdp['prefecture'] = merged_gdp['prefecture'].apply(lambda x: ''.join(c for c in unicodedata.normalize('NFD', x) if unicodedata.category(c) != 'Mn'))

merged_gdp
# Out:
#                             customer_id          geographical_region_of_shop  \
# 0      a702193e88fbcd649e6eec90d67d5a06                              χαλκίδα
# 1      a3b494cede85bc23a1d0551bf8a11ada                     χολαργός-παπάγου
# 2      2c524856cc61e2d59dbbd41c453fbe1c                               νίκαια
# 3      2d1d18d506ff73f0dc94d240fab0815f          αθήνα-εξάρχεια-πανεπιστήμιο
# 4      dce41e4eb4a3dd31c0e526da4b1b3474                                βόλος
# ...                                 ...                                  ...
# 24993  62e1b3685498018c6367afce605aa701                                  κώς
# 24994  17932beb378abff1ee75a93e70950024                            κερατσίνι
# 24995  2061b4ac8aa46c364e81567b3808df9d                 θεσσαλονίκη-άνω πόλη
# 24996  25064a84704ce206447b6a94c03d9da9  αθήνα-ομόνοια-πλ. βάθης-στ. λαρίσης
# 24997  8fe251d7f6d28e9f65f9c980fc3d409e                           κορυδαλλός
#
#        order_id               prefecture      GDP
# 0           557                   ευβοια  13415.0
# 1           435    βορειος τομεας αθηνων  25665.0
# 2           423                 πειραιας  18143.0
# 3           382  κεντρικος τομεας αθηνων  30454.0
# 4           371                 μαγνησια  11668.0
# ...         ...                      ...      ...
# 24993         5                      κως  12428.0
# 24994         4                 πειραιας  18143.0
# 24995         3              θεσσαλονικη  13091.0
# 24996         3  κεντρικος τομεας αθηνων  30454.0
# 24997         2                 πειραιας  18143.0
#
# [24998 rows x 5 columns]

# %%
import unicodedata

merged_gdp['geographical_region_of_shop'] = merged_gdp['geographical_region_of_shop'].apply(lambda x: ''.join(c for c in unicodedata.normalize('NFD', x) if unicodedata.category(c) != 'Mn'))

merged_gdp
# Out:
#                             customer_id          geographical_region_of_shop  \
# 0      a702193e88fbcd649e6eec90d67d5a06                              χαλκιδα
# 1      a3b494cede85bc23a1d0551bf8a11ada                     χολαργος-παπαγου
# 2      2c524856cc61e2d59dbbd41c453fbe1c                               νικαια
# 3      2d1d18d506ff73f0dc94d240fab0815f          αθηνα-εξαρχεια-πανεπιστημιο
# 4      dce41e4eb4a3dd31c0e526da4b1b3474                                βολος
# ...                                 ...                                  ...
# 24993  62e1b3685498018c6367afce605aa701                                  κως
# 24994  17932beb378abff1ee75a93e70950024                            κερατσινι
# 24995  2061b4ac8aa46c364e81567b3808df9d                 θεσσαλονικη-ανω πολη
# 24996  25064a84704ce206447b6a94c03d9da9  αθηνα-ομονοια-πλ. βαθης-στ. λαρισης
# 24997  8fe251d7f6d28e9f65f9c980fc3d409e                           κορυδαλλος
#
#        order_id               prefecture      GDP
# 0           557                   ευβοια  13415.0
# 1           435    βορειος τομεας αθηνων  25665.0
# 2           423                 πειραιας  18143.0
# 3           382  κεντρικος τομεας αθηνων  30454.0
# 4           371                 μαγνησια  11668.0
# ...         ...                      ...      ...
# 24993         5                      κως  12428.0
# 24994         4                 πειραιας  18143.0
# 24995         3              θεσσαλονικη  13091.0
# 24996         3  κεντρικος τομεας αθηνων  30454.0
# 24997         2                 πειραιας  18143.0
#
# [24998 rows x 5 columns]

# %%
merged_gdp_pop = pd.merge(merged_gdp, census[['dimos', 'population']],  left_on='prefecture', right_on='dimos',how='outer')

# %%
merged_gdp_pop = merged_gdp_pop[merged_gdp_pop['customer_id'].notnull()]
merged_gdp_pop
# Out:
#                             customer_id geographical_region_of_shop  order_id  \
# 0      a702193e88fbcd649e6eec90d67d5a06                     χαλκιδα     557.0
# 1      e58ce6707a77204cc91293890928c542                     χαλκιδα     184.0
# 2      2a2398b958dca74dfd531f43bd220344                     χαλκιδα     165.0
# 3      1fcbc95efd34aabcd378d7838acc97f9                     χαλκιδα     163.0
# 4      9c6671899b515212656894c6af46408f                     χαλκιδα     145.0
# ...                                 ...                         ...       ...
# 24993  c344fffaf396e47d1cfd4e557920d370                       σαμος      28.0
# 24994  679dcfccf433bf422b87ac82e1d88f66                       σαμος      27.0
# 24995  01a5d4b270516a2360992eb9259d5ff2                   καρπενησι      35.0
# 24996  0a175605e3c3700075a175431845b9a2                 ηγουμενιτσα      12.0
# 24997  2c45872d3b2270802961e553a5932020                     φλωρινα      12.0
#
#       prefecture      GDP      dimos  population
# 0         ευβοια  13415.0     ευβοια    213179.0
# 1         ευβοια  13415.0     ευβοια    213179.0
# 2         ευβοια  13415.0     ευβοια    213179.0
# 3         ευβοια  13415.0     ευβοια    213179.0
# 4         ευβοια  13415.0     ευβοια    213179.0
# ...          ...      ...        ...         ...
# 24993      σαμος   9835.0      σαμος     30200.0
# 24994      σαμος   9835.0      σαμος     30200.0
# 24995  ευρυτανια   9417.0  ευρυτανια     24545.0
# 24996  θεσπρωτια  11338.0  θεσπρωτια     47947.0
# 24997    φλωρινα  14547.0    φλωρινα     50921.0
#
# [24998 rows x 7 columns]

# %%
merged_gdp_pop[merged_gdp_pop.population.isnull()]
# Out:
#                             customer_id geographical_region_of_shop  order_id  \
# 9934   c69355a42d3f413cb3faca62424bd6d0           ηρακλειο κρητης 1     366.0
# 9935   88745182e0e56541f955b6deb7a40da6                χανια κρητης     325.0
# 9936   2ba8082ba3bd5a954d156e77df02cfe3           ηρακλειο κρητης 1     311.0
# 9937   a3e9616fc241ff5c8b3665575cc11e6a           ηρακλειο κρητης 2     288.0
# 9938   7d3d0e47e9cac2f339b9a09c71ac6c3c           ηρακλειο κρητης 1     286.0
# ...                                 ...                         ...       ...
# 11186  69655c5a117de3b70ca86dd6c0c6299c           ηρακλειο κρητης 2       9.0
# 11187  daaeb8ecd39ff8d3481e6b0113392d25           ηρακλειο κρητης 1       8.0
# 24980  6c4754042e62ffe148e5306f35513b06                       λερος      43.0
# 24981  f7e540d2a976023e5bc7363bf2ed7da5                       λερος      38.0
# 24982  ac9c6dc5d6f6b0034097a4828556da05                       λερος      29.0
#
#          prefecture      GDP dimos  population
# 9934          κρητη  12374.0   NaN         NaN
# 9935          κρητη  12374.0   NaN         NaN
# 9936          κρητη  12374.0   NaN         NaN
# 9937          κρητη  12374.0   NaN         NaN
# 9938          κρητη  12374.0   NaN         NaN
# ...             ...      ...   ...         ...
# 11186         κρητη  12374.0   NaN         NaN
# 11187         κρητη  12374.0   NaN         NaN
# 24980  νοτιο αιγαιο  14572.0   NaN         NaN
# 24981  νοτιο αιγαιο  14572.0   NaN         NaN
# 24982  νοτιο αιγαιο  14572.0   NaN         NaN
#
# [1257 rows x 7 columns]

# %% [markdown]
# Fill some values that can not match manually :

# %%
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'λερος') , 'population'] =7.917
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'ιεραπετρα κρητης') , 'population']=73258
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'σητεια κρητης') , 'population']=73258
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'φαιστος') | (merged_gdp_pop['geographical_region_of_shop'] == 'ηρακλειο κρητης 1'), 'population'] =285528
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'ηρακλειο κρητης 2') | (merged_gdp_pop['geographical_region_of_shop'] == 'ηρακλειο κρητης 3'), 'population'] =285528
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'χανια κρητης') , 'population'] =144259
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'αγιος νικολαος κρητης') , 'population'] =285528
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'ρεθυμνο κρητης') , 'population'] =79801
merged_gdp_pop.loc[(merged_gdp_pop['geographical_region_of_shop'] == 'αγιος νικολαος κρητης'), 'population'] =73258

# %% [markdown]
# Check

# %%
merged_gdp_pop[merged_gdp_pop.population.isnull()]
# Out:
# Empty DataFrame
# Columns: [customer_id, geographical_region_of_shop, order_id, prefecture, GDP, dimos, population]
# Index: []

# %%
customers_df = customers_df.merge(merged_gdp_pop[['customer_id','prefecture','GDP','population']], on='customer_id')
customers_df
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']  12.452941
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...   8.583750
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']   3.369231
# 3                                   ['Pizza', 'Καφέδες']   2.500000
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...   9.717021
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...  18.620833
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']  10.321875
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...  16.546667
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...   6.680000
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']   7.977778
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.411765                      0.705882          0.294118
# 1                 2.475000                      1.050000          0.475000
# 2                 1.000000                      0.230769          0.000000
# 3                 1.102041                      0.081633          0.000000
# 4                 2.872340                      0.787234          0.595745
# ...                    ...                           ...               ...
# 24993             3.833333                      2.500000          0.583333
# 24994             3.812500                      1.687500          0.875000
# 24995             4.200000                      1.266667          0.466667
# 24996             2.400000                      1.150000          0.700000
# 24997             1.555556                      0.555556          0.111111
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.000000                       0.0          0.000000
# 1                     0.150000                       0.0          0.625000
# 2                     0.000000                       0.0          0.923077
# 3                     0.000000                       0.0          0.000000
# 4                     0.000000                       0.0          0.574468
# ...                        ...                       ...               ...
# 24993                 0.166667                       0.0          0.583333
# 24994                 0.062500                       0.0          0.250000
# 24995                 0.000000                       0.0          0.866667
# 24996                 0.000000                       0.0          0.400000
# 24997                 0.000000                       0.0          0.888889
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.323529               True      0.000000        0.058824
# 1              0.000000              False      0.250000        0.450000
# 2              0.000000              False      0.384615        0.153846
# 3              0.000000              False      0.836735        0.163265
# 4              0.000000              False      0.021277        0.212766
# ...                 ...                ...           ...             ...
# 24993          0.500000              False      0.166667        0.250000
# 24994          0.000000              False      0.000000        0.500000
# 24995          0.000000              False      0.000000        0.000000
# 24996          0.000000              False      0.100000        0.350000
# 24997          0.055556              False      0.555556        0.166667
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.941176                      False           0.0  Mystery Maven
# 1        0.300000                      False           0.0  Mystery Maven
# 2        0.461538                      False           0.0  Mystery Maven
# 3        0.000000                      False           0.0  Mystery Maven
# 4        0.765957                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993    0.583333                      False           0.0  Mystery Maven
# 24994    0.500000                      False           0.0  Mystery Maven
# 24995    1.000000                      False           0.0  Mystery Maven
# 24996    0.550000                      False           0.0  Mystery Maven
# 24997    0.277778                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                0.264706            0.735294                       Αθήνα
# 1                0.225000            0.775000                       Αθήνα
# 2                0.307692            0.692308                      Κιλκίς
# 3                0.183673            0.816327                      Σπάρτη
# 4                0.319149            0.680851                       Αθήνα
# ...                   ...                 ...                         ...
# 24993            0.583333            0.416667                       Αθήνα
# 24994            0.250000            0.750000                       Αθήνα
# 24995            0.533333            0.466667                       Αθήνα
# 24996            0.350000            0.650000                       Αθήνα
# 24997            0.111111            0.888889                       Αθήνα
#
#        coffee_percentage  percentage_with_more_than_2  \
# 0               0.000000                     0.382353
# 1               0.425000                     0.175000
# 2               0.692308                     0.000000
# 3               0.020408                     0.000000
# 4               0.191489                     0.234043
# ...                  ...                          ...
# 24993           0.250000                     0.166667
# 24994           0.312500                     0.125000
# 24995           0.133333                     0.400000
# 24996           0.500000                     0.000000
# 24997           0.722222                     0.055556
#
#                     prefecture      GDP  population
# 0         νοτιος τομεας αθηνων  18127.0    425112.0
# 1         νοτιος τομεας αθηνων  18127.0    425112.0
# 2                       κιλκις  10609.0     85885.0
# 3                      λακωνια  11864.0     87104.0
# 4         νοτιος τομεας αθηνων  18127.0    425112.0
# ...                        ...      ...         ...
# 24993    δυτικος τομεας αθηνων  10608.0    405623.0
# 24994    βορειος τομεας αθηνων  25665.0    481758.0
# 24995    δυτικος τομεας αθηνων  10608.0    405623.0
# 24996                    αχαια  12370.0    296574.0
# 24997  κεντρικος τομεας αθηνων  30454.0    717373.0
#
# [24998 rows x 37 columns]

# %%
customers_df['GDP'] = customers_df['GDP'].round().astype(int)
customers_df['population'] = customers_df['population'].round().astype(int)

# %%
customers_df2=customers_df.copy()

# %%
# Round all floats in the DataFrame to two decimal places
customers_df2 = customers_df2.round(2)

# %%
customers_df2.head()
# Out:
#                         customer_id  recency  monetary  num_orders  \
# 0  0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1  0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2  00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3  000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4  0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
#
#    days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0          479         17        150               52             2
# 1         1273         23         99               61             9
# 2          263          4         13                5             3
# 3          501          2         54                5             2
# 4         1972         23        135               58             7
#
#                                           categories        city      region  \
# 0  [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...   ['Αθήνα']   ['Αθήνα']
# 1  [Κοτόπουλο, Our Burger Meals | Single Burger, ...   ['Αθήνα']   ['Αθήνα']
# 2                [Καφέδες, Club sandwiches, Burgers]  ['Κιλκίς']  ['Κιλκίς']
# 3            [Καφέδες, Sandwiches, Σαλάτες, Burgers]  ['Σπάρτη']  ['Σπάρτη']
# 4  [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...   ['Αθήνα']   ['Αθήνα']
#
#                                         shop_regions  \
# 0                                     ['Νέα Σμύρνη']
# 1  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2                                         ['Κιλκίς']
# 3                                         ['Σπάρτη']
# 4                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
#
#                                             cuisines  avg_spent  \
# 0                        ['Σουβλάκια', 'Μαγειρευτά']      12.45
# 1  ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...       8.58
# 2                     ['Pizza', 'Καφέδες', 'Κρέπες']       3.37
# 3                               ['Pizza', 'Καφέδες']       2.50
# 4  ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...       9.72
#
#    avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.41                          0.71              0.29
# 1                 2.48                          1.05              0.48
# 2                 1.00                          0.23              0.00
# 3                 1.10                          0.08              0.00
# 4                 2.87                          0.79              0.60
#
#    perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.00                       0.0              0.00
# 1                     0.15                       0.0              0.62
# 2                     0.00                       0.0              0.92
# 3                     0.00                       0.0              0.00
# 4                     0.00                       0.0              0.57
#
#    perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.32               True          0.00            0.06
# 1              0.00              False          0.25            0.45
# 2              0.00              False          0.38            0.15
# 3              0.00              False          0.84            0.16
# 4              0.00              False          0.02            0.21
#
#    night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.94                      False           0.0  Mystery Maven
# 1        0.30                      False           0.0  Mystery Maven
# 2        0.46                      False           0.0  Mystery Maven
# 3        0.00                      False           0.0  Mystery Maven
# 4        0.77                      False           0.0  Mystery Maven
#
#    weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                0.26                0.74                       Αθήνα
# 1                0.22                0.78                       Αθήνα
# 2                0.31                0.69                      Κιλκίς
# 3                0.18                0.82                      Σπάρτη
# 4                0.32                0.68                       Αθήνα
#
#    coffee_percentage  percentage_with_more_than_2            prefecture  \
# 0               0.00                         0.38  νοτιος τομεας αθηνων
# 1               0.42                         0.18  νοτιος τομεας αθηνων
# 2               0.69                         0.00                κιλκις
# 3               0.02                         0.00               λακωνια
# 4               0.19                         0.23  νοτιος τομεας αθηνων
#
#      GDP  population
# 0  18127      425112
# 1  18127      425112
# 2  10609       85885
# 3  11864       87104
# 4  18127      425112

# %%
customers_df2.GDP.describe()
# Out:
# count    24998.000000
# mean     18323.757341
# std       7132.792427
# min       8944.000000
# 25%      12374.000000
# 50%      18127.000000
# 75%      25665.000000
# max      30454.000000
# Name: GDP, dtype: float64

# %%
# create a function to label the income class based on GDP
def label_city(gdp):
    if gdp > 18323:
        return 'High income'
    elif gdp > 12374:
        return 'Average income'
    else:
        return 'Low income'

# apply the function to create a new column with income labels
customers_df2['income_class'] = customers_df2['GDP'].apply(label_city)

# %%
customers_df2.head()
# Out:
#                         customer_id  recency  monetary  num_orders  \
# 0  0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1  0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2  00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3  000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4  0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
#
#    days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0          479         17        150               52             2
# 1         1273         23         99               61             9
# 2          263          4         13                5             3
# 3          501          2         54                5             2
# 4         1972         23        135               58             7
#
#                                           categories        city      region  \
# 0  [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...   ['Αθήνα']   ['Αθήνα']
# 1  [Κοτόπουλο, Our Burger Meals | Single Burger, ...   ['Αθήνα']   ['Αθήνα']
# 2                [Καφέδες, Club sandwiches, Burgers]  ['Κιλκίς']  ['Κιλκίς']
# 3            [Καφέδες, Sandwiches, Σαλάτες, Burgers]  ['Σπάρτη']  ['Σπάρτη']
# 4  [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...   ['Αθήνα']   ['Αθήνα']
#
#                                         shop_regions  \
# 0                                     ['Νέα Σμύρνη']
# 1  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2                                         ['Κιλκίς']
# 3                                         ['Σπάρτη']
# 4                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
#
#                                             cuisines  avg_spent  \
# 0                        ['Σουβλάκια', 'Μαγειρευτά']      12.45
# 1  ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...       8.58
# 2                     ['Pizza', 'Καφέδες', 'Κρέπες']       3.37
# 3                               ['Pizza', 'Καφέδες']       2.50
# 4  ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...       9.72
#
#    avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.41                          0.71              0.29
# 1                 2.48                          1.05              0.48
# 2                 1.00                          0.23              0.00
# 3                 1.10                          0.08              0.00
# 4                 2.87                          0.79              0.60
#
#    perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                     0.00                       0.0              0.00
# 1                     0.15                       0.0              0.62
# 2                     0.00                       0.0              0.92
# 3                     0.00                       0.0              0.00
# 4                     0.00                       0.0              0.57
#
#    perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.32               True          0.00            0.06
# 1              0.00              False          0.25            0.45
# 2              0.00              False          0.38            0.15
# 3              0.00              False          0.84            0.16
# 4              0.00              False          0.02            0.21
#
#    night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.94                      False           0.0  Mystery Maven
# 1        0.30                      False           0.0  Mystery Maven
# 2        0.46                      False           0.0  Mystery Maven
# 3        0.00                      False           0.0  Mystery Maven
# 4        0.77                      False           0.0  Mystery Maven
#
#    weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                0.26                0.74                       Αθήνα
# 1                0.22                0.78                       Αθήνα
# 2                0.31                0.69                      Κιλκίς
# 3                0.18                0.82                      Σπάρτη
# 4                0.32                0.68                       Αθήνα
#
#    coffee_percentage  percentage_with_more_than_2            prefecture  \
# 0               0.00                         0.38  νοτιος τομεας αθηνων
# 1               0.42                         0.18  νοτιος τομεας αθηνων
# 2               0.69                         0.00                κιλκις
# 3               0.02                         0.00               λακωνια
# 4               0.19                         0.23  νοτιος τομεας αθηνων
#
#      GDP  population    income_class
# 0  18127      425112  Average income
# 1  18127      425112  Average income
# 2  10609       85885      Low income
# 3  11864       87104      Low income
# 4  18127      425112  Average income

# %%
customers_df2[customers_df2.avg_items_per_order>19]
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 15477  9f18fde21cc7e22a2400b2b43761fe34        6     221.8          19
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 15477           76          2        369                9             2
#
#                                               categories       city  \
# 15477  [Κουλούρια μπουκίτσες γεμιστά, Παγωτά, Sandwic...  ['Αθήνα']
#
#           region        shop_regions                  cuisines  avg_spent  \
# 15477  ['Αθήνα']  ['Αγία Παρασκευή']  ['Κουλούρια', 'Burgers']      11.67
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 15477                19.42                          0.32               1.0
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 15477                     0.89                       0.0              0.89
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 15477               0.0               True          0.89            0.11
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 15477         0.0                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 15477                 0.0                 1.0                       Αθήνα
#
#        coffee_percentage  percentage_with_more_than_2             prefecture  \
# 15477                0.0                         2.63  βορειος τομεας αθηνων
#
#          GDP  population income_class
# 15477  25665      481758  High income

# %% [markdown]
# Some statistics to see the range in values when it comes to average number of orders, average number of order items , averange number of categories per order, and percentage of ordes with more than two items from the same category!

# %%
customers_df2.avg_items_per_order.describe()
# Out:
# count    24998.000000
# mean         3.062298
# std          1.119403
# min          1.000000
# 25%          2.310000
# 50%          2.860000
# 75%          3.570000
# max         19.420000
# Name: avg_items_per_order, dtype: float64

# %%
customers_df2.percentage_with_more_than_2.describe()
# Out:
# count    24998.000000
# mean         0.334054
# std          0.305235
# min          0.000000
# 25%          0.110000
# 50%          0.250000
# 75%          0.470000
# max          4.170000
# Name: percentage_with_more_than_2, dtype: float64

# %%
customers_df2.avg_spent.describe()
# Out:
# count    24998.000000
# mean        10.223493
# std          4.773567
# min          0.500000
# 25%          7.020000
# 50%          9.350000
# 75%         12.397500
# max         68.320000
# Name: avg_spent, dtype: float64

# %%
customers_df2.avg_num_categories_per_order.describe()
# Out:
# count    24998.000000
# mean         0.941318
# std          0.430646
# min          0.020000
# 25%          0.630000
# 50%          0.900000
# 75%          1.210000
# max          3.310000
# Name: avg_num_categories_per_order, dtype: float64

# %%
customers_df2.dtypes
# Out:
# customer_id                      object
# recency                           int64
# monetary                        float64
# num_orders                        int64
# days_active                       int64
# num_shops                         int64
# num_items                         int64
# var_order_items                   int64
# num_cuisines                      int64
# categories                       object
# city                             object
# region                           object
# shop_regions                     object
# cuisines                         object
# avg_spent                       float64
# avg_items_per_order             float64
# avg_num_categories_per_order    float64
# perc_chain_shops                float64
# perc_delivered_by_efood         float64
# perc_has_discount_coupon        float64
# perc_paid_online                float64
# perc_from_pinata                float64
# orders_every_week                  bool
# morning_perc                    float64
# afternoon_perc                  float64
# night_perc                      float64
# ordered_3_days_every_week          bool
# scores_count                    float64
# leaves_reviews                   object
# weekend_orders_pct              float64
# weekday_orders_pct              float64
# geographical_region_of_user      object
# coffee_percentage               float64
# percentage_with_more_than_2     float64
# prefecture                       object
# GDP                               int64
# population                        int64
# income_class                     object
# dtype: object

# %% [markdown]
# ### Histograms, Density plots and Boxplots for the columns we are interested in, to undestand their distibution, range of values and outliers better

# %%
# Set style to 'ggplot'
plt.style.use('ggplot')

# Define a dictionary for custom colors
#colors = {'avg_items_per_order': '#FFC300', 'avg_spent': '#FF5733', 'avg_num_categories_per_order': '#C70039', 'percentage_with_more_than_2': '#be33ff'}
#colors = ['#FFC300', '#FF5733', '#C70039', '#900C3F']

# Plot histograms of multiple columns with custom colors
#customers_df2[['avg_items_per_order', 'avg_spent', 'avg_num_categories_per_order','percentage_with_more_than_2']].hist(bins=10, color=colors, alpha=0.7, figsize=(18, 14))
#plt.hist([customers_df2['avg_items_per_order'], customers_df2['avg_spent'], customers_df2['avg_num_categories_per_order'], customers_df2['percentage_with_more_than_2']], color=colors)
customers_df2.hist(column=['avg_items_per_order', 'avg_spent', 'avg_num_categories_per_order', 'percentage_with_more_than_2'], figsize=(10, 8))

# Set axis labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
#plt.title('Histograms of avg_items_per_order, avg_spent,avg_num_categories_per_order and percentage_with_more_than_2')
# Show the legend with custom labels
#plt.legend(['avg_items_per_order', 'avg_spent', 'avg_num_categories_per_order', 'percentage_with_more_than_2'])

# Set the font size
plt.rcParams.update({'font.size': 14})

# Display the plot
plt.show()

# %%
# Visualizing the distributions before and after log transformation.
target = ['avg_items_per_order', 'avg_spent',	'avg_num_categories_per_order', 'percentage_with_more_than_2']
plt.figure(figsize=(13,6), dpi=90)
for n,col in enumerate(target):
  plt.subplot(2, 2, n+1)
  sns.distplot(customers_df2[col])
  plt.title(col.title())
  plt.tight_layout()

# %%
plt.style.use('ggplot')
# Create a boxplot for each variable
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

sns.boxplot(y=customers_df2['avg_items_per_order'], ax=axes[0],color='darkorange')
sns.boxplot(y=customers_df2['avg_spent'], ax=axes[1],color='orangered')
sns.boxplot(y=customers_df2['avg_num_categories_per_order'], ax=axes[2],color='goldenrod')

# Set titles for each subplot
axes[0].set_title('Avg. Items per Order')
axes[1].set_title('Avg. Spent')
axes[2].set_title('Avg. Categories per Order')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Define quartiles and thresholds for the variables that will be used to decide the household size

# %%
# Calculate the quartiles of the variables
q1 = customers_df2[['avg_items_per_order', 'avg_spent', 'avg_num_categories_per_order']].quantile(0.25)
q2 = customers_df2[['avg_items_per_order', 'avg_spent', 'avg_num_categories_per_order']].quantile(0.5)
q3 = customers_df2[['avg_items_per_order', 'avg_spent', 'avg_num_categories_per_order']].quantile(0.75)

# %%
# Define the category thresholds
category_thresholds = {
    'avg_items_per_order': [
        (float('-inf'), q1['avg_items_per_order']),
        (q1['avg_items_per_order'], q2['avg_items_per_order']),
        (q2['avg_items_per_order'], q3['avg_items_per_order']),
        (q3['avg_items_per_order'], float('inf'))
    ],
    'avg_spent': [
        (float('-inf'), q1['avg_spent']),
        (q1['avg_spent'], q2['avg_spent']),
        (q2['avg_spent'], q3['avg_spent']),
        (q3['avg_spent'], float('inf'))
    ],
    'avg_num_categories_per_order': [
        (float('-inf'), q1['avg_num_categories_per_order']),
        (q1['avg_num_categories_per_order'], q2['avg_num_categories_per_order']),
        (q2['avg_num_categories_per_order'], q3['avg_num_categories_per_order']),
        (q3['avg_num_categories_per_order'], float('inf'))
    ]
}

# %%
category_thresholds
# Out:
# {'avg_items_per_order': [(-inf, 2.31),
#   (2.31, 2.86),
#   (2.86, 3.57),
#   (3.57, inf)],
#  'avg_spent': [(-inf, 7.02), (7.02, 9.35), (9.35, 12.3975), (12.3975, inf)],
#  'avg_num_categories_per_order': [(-inf, 0.63),
#   (0.63, 0.9),
#   (0.9, 1.21),
#   (1.21, inf)]}

# %%
# Define the categories based on the quartiles
def categorize(row):
    for col, thresholds in category_thresholds.items():
        if row[col] < thresholds[0][0]:
            return None
        for i, thresh in enumerate(thresholds):
            if row[col] < thresh[1]:
                return ['Single or Couple', 'Small Household', 'Small or Medium Household', 'Medium Household'][i]
    return None

customers_df2['household_size2'] = customers_df2.apply(categorize, axis=1)

# %%
customers_df2
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']      12.45
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...       8.58
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']       3.37
# 3                                   ['Pizza', 'Καφέδες']       2.50
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...       9.72
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...      18.62
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']      10.32
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...      16.55
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...       6.68
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']       7.98
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                     4.41                          0.71              0.29
# 1                     2.48                          1.05              0.48
# 2                     1.00                          0.23              0.00
# 3                     1.10                          0.08              0.00
# 4                     2.87                          0.79              0.60
# ...                    ...                           ...               ...
# 24993                 3.83                          2.50              0.58
# 24994                 3.81                          1.69              0.88
# 24995                 4.20                          1.27              0.47
# 24996                 2.40                          1.15              0.70
# 24997                 1.56                          0.56              0.11
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                         0.00                       0.0              0.00
# 1                         0.15                       0.0              0.62
# 2                         0.00                       0.0              0.92
# 3                         0.00                       0.0              0.00
# 4                         0.00                       0.0              0.57
# ...                        ...                       ...               ...
# 24993                     0.17                       0.0              0.58
# 24994                     0.06                       0.0              0.25
# 24995                     0.00                       0.0              0.87
# 24996                     0.00                       0.0              0.40
# 24997                     0.00                       0.0              0.89
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0                  0.32               True          0.00            0.06
# 1                  0.00              False          0.25            0.45
# 2                  0.00              False          0.38            0.15
# 3                  0.00              False          0.84            0.16
# 4                  0.00              False          0.02            0.21
# ...                 ...                ...           ...             ...
# 24993              0.50              False          0.17            0.25
# 24994              0.00              False          0.00            0.50
# 24995              0.00              False          0.00            0.00
# 24996              0.00              False          0.10            0.35
# 24997              0.06              False          0.56            0.17
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0            0.94                      False           0.0  Mystery Maven
# 1            0.30                      False           0.0  Mystery Maven
# 2            0.46                      False           0.0  Mystery Maven
# 3            0.00                      False           0.0  Mystery Maven
# 4            0.77                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993        0.58                      False           0.0  Mystery Maven
# 24994        0.50                      False           0.0  Mystery Maven
# 24995        1.00                      False           0.0  Mystery Maven
# 24996        0.55                      False           0.0  Mystery Maven
# 24997        0.28                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                    0.26                0.74                       Αθήνα
# 1                    0.22                0.78                       Αθήνα
# 2                    0.31                0.69                      Κιλκίς
# 3                    0.18                0.82                      Σπάρτη
# 4                    0.32                0.68                       Αθήνα
# ...                   ...                 ...                         ...
# 24993                0.58                0.42                       Αθήνα
# 24994                0.25                0.75                       Αθήνα
# 24995                0.53                0.47                       Αθήνα
# 24996                0.35                0.65                       Αθήνα
# 24997                0.11                0.89                       Αθήνα
#
#        coffee_percentage  percentage_with_more_than_2  \
# 0                   0.00                         0.38
# 1                   0.42                         0.18
# 2                   0.69                         0.00
# 3                   0.02                         0.00
# 4                   0.19                         0.23
# ...                  ...                          ...
# 24993               0.25                         0.17
# 24994               0.31                         0.12
# 24995               0.13                         0.40
# 24996               0.50                         0.00
# 24997               0.72                         0.06
#
#                     prefecture    GDP  population    income_class  \
# 0         νοτιος τομεας αθηνων  18127      425112  Average income
# 1         νοτιος τομεας αθηνων  18127      425112  Average income
# 2                       κιλκις  10609       85885      Low income
# 3                      λακωνια  11864       87104      Low income
# 4         νοτιος τομεας αθηνων  18127      425112  Average income
# ...                        ...    ...         ...             ...
# 24993    δυτικος τομεας αθηνων  10608      405623      Low income
# 24994    βορειος τομεας αθηνων  25665      481758     High income
# 24995    δυτικος τομεας αθηνων  10608      405623      Low income
# 24996                    αχαια  12370      296574      Low income
# 24997  κεντρικος τομεας αθηνων  30454      717373     High income
#
#                  household_size2
# 0               Medium Household
# 1                Small Household
# 2               Single or Couple
# 3               Single or Couple
# 4      Small or Medium Household
# ...                          ...
# 24993           Medium Household
# 24994           Medium Household
# 24995           Medium Household
# 24996            Small Household
# 24997           Single or Couple
#
# [24998 rows x 39 columns]

# %%
# Define a function to categorize customers based on their order frequency and other variables
# def categorize_customers(df):
#     # Calculate the total number of items purchased
#     customers_df2['total_items'] = customers_df2['number_of_orders'] * customers_df2['number_of_items_per_order']
    
#     # Calculate the average number of items per order
#     customers_df2['avg_items_per_order'] = customers_df2['total_items'] / customers_df2['number_of_orders']
     
#     # Create a dictionary to map order frequency to household size
#     frequency_map = {
#         '1-2 times': 1,
#         '3-4 times': 2,
#         '5-6 times': 3,
#         '7+ times': 4
#     }
    
#     # Map order frequency to household size
#     customers_df2['household_size'] = customers_df2['frequency_of_orders'].map(frequency_map)
  
  # Create a function to categorize customers based on their household size and other variables
def categorize(row):
    if row['avg_items_per_order'] <= 2.86:
        if row['avg_spent'] <= 7:
            if row['avg_num_categories_per_order'] <= 0.6:
                return 'Single or Couple'
            else:
                return 'Small Household'
        else:
            if row['avg_num_categories_per_order'] <= 0.6:
                return 'Single or Couple'
            else:
                return 'Small or Medium Household'
    else:
        if row['avg_spent'] <= 9:
            if row['avg_num_categories_per_order'] <= 0.6:
                return 'Small or Medium Household'
            else:
                return 'Medium Household'
        else:
            if row['avg_num_categories_per_order'] <= 0.6:
                return 'Small or Medium Household'
            else:
                return 'Large Household'

    return customers_df2


# Apply the categorize function to each row of the DataFrame
customers_df2['household_size'] = customers_df2.apply(categorize, axis=1)

# %%
customers_df2[customers_df2['customer_id']=='0001496e540173a40362759ed10b3ce2']
# Out:
#                         customer_id  recency  monetary  num_orders  \
# 0  0001496e540173a40362759ed10b3ce2        2     423.4          34
#
#    days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0          479         17        150               52             2
#
#                                           categories       city     region  \
# 0  [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...  ['Αθήνα']  ['Αθήνα']
#
#      shop_regions                     cuisines  avg_spent  \
# 0  ['Νέα Σμύρνη']  ['Σουβλάκια', 'Μαγειρευτά']      12.45
#
#    avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                 4.41                          0.71              0.29
#
#    perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                      0.0                       0.0               0.0
#
#    perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0              0.32               True           0.0            0.06
#
#    night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0        0.94                      False           0.0  Mystery Maven
#
#    weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                0.26                0.74                       Αθήνα
#
#    coffee_percentage  percentage_with_more_than_2            prefecture  \
# 0                0.0                         0.38  νοτιος τομεας αθηνων
#
#      GDP  population    income_class   household_size2   household_size
# 0  18127      425112  Average income  Medium Household  Large Household

# %%
df[df.customer_id=='9f18fde21cc7e22a2400b2b43761fe34'] #company
# Out:
#                               customer_id                          order_id  \
# 137735   9f18fde21cc7e22a2400b2b43761fe34  84fd7a5e412b2412a9acd4ff153aa8d0
# 137736   9f18fde21cc7e22a2400b2b43761fe34  84fd7a5e412b2412a9acd4ff153aa8d0
# 228488   9f18fde21cc7e22a2400b2b43761fe34  d5a401abdb2ca9c15377f293f020de85
# 228489   9f18fde21cc7e22a2400b2b43761fe34  d5a401abdb2ca9c15377f293f020de85
# 228490   9f18fde21cc7e22a2400b2b43761fe34  d5a401abdb2ca9c15377f293f020de85
# 255343   9f18fde21cc7e22a2400b2b43761fe34  8529ac31f213598dc28467d191857c85
# 255344   9f18fde21cc7e22a2400b2b43761fe34  8529ac31f213598dc28467d191857c85
# 255345   9f18fde21cc7e22a2400b2b43761fe34  8529ac31f213598dc28467d191857c85
# 285646   9f18fde21cc7e22a2400b2b43761fe34  e04bac2b47b878067b256f7a30ae5b30
# 285647   9f18fde21cc7e22a2400b2b43761fe34  e04bac2b47b878067b256f7a30ae5b30
# 285648   9f18fde21cc7e22a2400b2b43761fe34  e04bac2b47b878067b256f7a30ae5b30
# 285649   9f18fde21cc7e22a2400b2b43761fe34  e04bac2b47b878067b256f7a30ae5b30
# 315984   9f18fde21cc7e22a2400b2b43761fe34  346a8c1c5ac7e1cc9e554dd0791639f1
# 315985   9f18fde21cc7e22a2400b2b43761fe34  346a8c1c5ac7e1cc9e554dd0791639f1
# 315986   9f18fde21cc7e22a2400b2b43761fe34  346a8c1c5ac7e1cc9e554dd0791639f1
# 423524   9f18fde21cc7e22a2400b2b43761fe34  8636cbb52f131380b1b93e00afda4937
# 423525   9f18fde21cc7e22a2400b2b43761fe34  8636cbb52f131380b1b93e00afda4937
# 423526   9f18fde21cc7e22a2400b2b43761fe34  8636cbb52f131380b1b93e00afda4937
# 447536   9f18fde21cc7e22a2400b2b43761fe34  d939c058546cf48e0556d5d0e94b96a8
# 447537   9f18fde21cc7e22a2400b2b43761fe34  d939c058546cf48e0556d5d0e94b96a8
# 449760   9f18fde21cc7e22a2400b2b43761fe34  4b909b8dcd077a3428afc62d6064d466
# 449761   9f18fde21cc7e22a2400b2b43761fe34  4b909b8dcd077a3428afc62d6064d466
# 449762   9f18fde21cc7e22a2400b2b43761fe34  4b909b8dcd077a3428afc62d6064d466
# 533557   9f18fde21cc7e22a2400b2b43761fe34  ace96a5553c3ae5236d69cf4e79a950e
# 533558   9f18fde21cc7e22a2400b2b43761fe34  ace96a5553c3ae5236d69cf4e79a950e
# 533559   9f18fde21cc7e22a2400b2b43761fe34  ace96a5553c3ae5236d69cf4e79a950e
# 533560   9f18fde21cc7e22a2400b2b43761fe34  ace96a5553c3ae5236d69cf4e79a950e
# 555652   9f18fde21cc7e22a2400b2b43761fe34  03095bf11959384a63f442217ad55302
# 555653   9f18fde21cc7e22a2400b2b43761fe34  03095bf11959384a63f442217ad55302
# 555654   9f18fde21cc7e22a2400b2b43761fe34  03095bf11959384a63f442217ad55302
# 585478   9f18fde21cc7e22a2400b2b43761fe34  857365b203ff622b3fa5e266e901b8e9
# 585479   9f18fde21cc7e22a2400b2b43761fe34  857365b203ff622b3fa5e266e901b8e9
# 585480   9f18fde21cc7e22a2400b2b43761fe34  857365b203ff622b3fa5e266e901b8e9
# 598909   9f18fde21cc7e22a2400b2b43761fe34  63effafa063f6c228f3461cfa0a32a4e
# 598910   9f18fde21cc7e22a2400b2b43761fe34  63effafa063f6c228f3461cfa0a32a4e
# 598911   9f18fde21cc7e22a2400b2b43761fe34  63effafa063f6c228f3461cfa0a32a4e
# 613285   9f18fde21cc7e22a2400b2b43761fe34  ecbc3839593de0aa2a8348e6896100c1
# 613286   9f18fde21cc7e22a2400b2b43761fe34  ecbc3839593de0aa2a8348e6896100c1
# 613287   9f18fde21cc7e22a2400b2b43761fe34  ecbc3839593de0aa2a8348e6896100c1
# 759997   9f18fde21cc7e22a2400b2b43761fe34  972da31b5efcac6ac20d5238dd886917
# 759998   9f18fde21cc7e22a2400b2b43761fe34  972da31b5efcac6ac20d5238dd886917
# 759999   9f18fde21cc7e22a2400b2b43761fe34  972da31b5efcac6ac20d5238dd886917
# 881974   9f18fde21cc7e22a2400b2b43761fe34  6e15de3251e2b54b21ae60725ab5c5f6
# 881975   9f18fde21cc7e22a2400b2b43761fe34  6e15de3251e2b54b21ae60725ab5c5f6
# 881976   9f18fde21cc7e22a2400b2b43761fe34  6e15de3251e2b54b21ae60725ab5c5f6
# 915177   9f18fde21cc7e22a2400b2b43761fe34  03cf3c1baa3170052747630436846ad7
# 915178   9f18fde21cc7e22a2400b2b43761fe34  03cf3c1baa3170052747630436846ad7
# 915179   9f18fde21cc7e22a2400b2b43761fe34  03cf3c1baa3170052747630436846ad7
# 915180   9f18fde21cc7e22a2400b2b43761fe34  03cf3c1baa3170052747630436846ad7
# 921132   9f18fde21cc7e22a2400b2b43761fe34  ade87612179eee0acf723061a9bb35d1
# 921133   9f18fde21cc7e22a2400b2b43761fe34  ade87612179eee0acf723061a9bb35d1
# 921134   9f18fde21cc7e22a2400b2b43761fe34  ade87612179eee0acf723061a9bb35d1
# 1370979  9f18fde21cc7e22a2400b2b43761fe34  9e5bda97d8aa7b321ed647ebb2f937e7
# 1370980  9f18fde21cc7e22a2400b2b43761fe34  9e5bda97d8aa7b321ed647ebb2f937e7
# 1370981  9f18fde21cc7e22a2400b2b43761fe34  9e5bda97d8aa7b321ed647ebb2f937e7
# 1394340  9f18fde21cc7e22a2400b2b43761fe34  7da57a95918caee927166cc0161f5ffb
# 1394341  9f18fde21cc7e22a2400b2b43761fe34  7da57a95918caee927166cc0161f5ffb
# 1394342  9f18fde21cc7e22a2400b2b43761fe34  7da57a95918caee927166cc0161f5ffb
#
#                   order_timestamp                            item_name  \
# 137735  2021-05-12 15:07:42+00:00         φιλετίνια κοτόπουλου goody`s
# 137736  2021-05-12 15:07:42+00:00      b&j strawberry cheesecake 100ml
# 228488  2021-04-23 08:09:02+00:00              κουλούρι κλασικό αφράτο
# 228489  2021-04-23 08:09:02+00:00             κουλούρι κλασικό τραγανό
# 228490  2021-04-23 08:09:02+00:00             μπουκίτσες με τυρί κρέμα
# 255343  2021-05-07 08:07:13+00:00             κουλούρι κλασικό τραγανό
# 255344  2021-05-07 08:07:13+00:00             μπουκίτσες με τυρί κρέμα
# 255345  2021-05-07 08:07:13+00:00                κουλούρι με τυρί arla
# 285646  2021-05-17 08:40:22+00:00                κουλούρι με τυρί arla
# 285647  2021-05-17 08:40:22+00:00             μπουκίτσες με τυρί κρέμα
# 285648  2021-05-17 08:40:22+00:00              κουλούρι κλασικό αφράτο
# 285649  2021-05-17 08:40:22+00:00             κουλούρι κλασικό τραγανό
# 315984  2021-05-11 08:12:59+00:00             μπουκίτσες με τυρί κρέμα
# 315985  2021-05-11 08:12:59+00:00             κουλούρι κλασικό τραγανό
# 315986  2021-05-11 08:12:59+00:00                κουλούρι με τυρί arla
# 423524  2021-04-08 08:51:04+00:00             μπουκίτσες με τυρί κρέμα
# 423525  2021-04-08 08:51:04+00:00              κουλούρι κλασικό αφράτο
# 423526  2021-04-08 08:51:04+00:00             κουλούρι κλασικό τραγανό
# 447536  2021-04-16 15:15:08+00:00      b&j strawberry cheesecake 100ml
# 447537  2021-04-16 15:15:08+00:00         φιλετίνια κοτόπουλου goody`s
# 449760  2021-05-05 08:21:20+00:00              κουλούρι κλασικό αφράτο
# 449761  2021-05-05 08:21:20+00:00             κουλούρι κλασικό τραγανό
# 449762  2021-05-05 08:21:20+00:00                κουλούρι με τυρί arla
# 533557  2021-04-05 08:43:54+00:00              κουλούρι κλασικό αφράτο
# 533558  2021-04-05 08:43:54+00:00            κουλούρι με μήλο & κανέλα
# 533559  2021-04-05 08:43:54+00:00             κουλούρι κλασικό τραγανό
# 533560  2021-04-05 08:43:54+00:00             μπουκίτσες με τυρί κρέμα
# 555652  2021-04-26 08:41:10+00:00              κουλούρι κλασικό αφράτο
# 555653  2021-04-26 08:41:10+00:00             κουλούρι κλασικό τραγανό
# 555654  2021-04-26 08:41:10+00:00             μπουκίτσες με τυρί κρέμα
# 585478  2021-04-16 08:07:03+00:00              κουλούρι κλασικό αφράτο
# 585479  2021-04-16 08:07:03+00:00             κουλούρι κλασικό τραγανό
# 585480  2021-04-16 08:07:03+00:00             μπουκίτσες με τυρί κρέμα
# 598909  2021-05-31 08:53:57+00:00                κουλούρι με τυρί arla
# 598910  2021-05-31 08:53:57+00:00             μπουκίτσες με τυρί κρέμα
# 598911  2021-05-31 08:53:57+00:00             κουλούρι κλασικό τραγανό
# 613285  2021-05-21 08:03:12+00:00                κουλούρι με τυρί arla
# 613286  2021-05-21 08:03:12+00:00             μπουκίτσες με τυρί κρέμα
# 613287  2021-05-21 08:03:12+00:00             κουλούρι κλασικό τραγανό
# 759997  2021-05-26 08:40:58+00:00                κουλούρι με τυρί arla
# 759998  2021-05-26 08:40:58+00:00             μπουκίτσες με τυρί κρέμα
# 759999  2021-05-26 08:40:58+00:00             κουλούρι κλασικό τραγανό
# 881974  2021-04-19 08:04:53+00:00              κουλούρι κλασικό αφράτο
# 881975  2021-04-19 08:04:53+00:00             κουλούρι κλασικό τραγανό
# 881976  2021-04-19 08:04:53+00:00             μπουκίτσες με τυρί κρέμα
# 915177  2021-04-30 08:20:27+00:00              κουλούρι κλασικό αφράτο
# 915178  2021-04-30 08:20:27+00:00              φρατζολάκι με τυρί arla
# 915179  2021-04-30 08:20:27+00:00             κουλούρι κλασικό τραγανό
# 915180  2021-04-30 08:20:27+00:00                κουλούρι με τυρί arla
# 921132  2021-04-02 08:12:52+00:00              κουλούρι κλασικό αφράτο
# 921133  2021-04-02 08:12:52+00:00             κουλούρι κλασικό τραγανό
# 921134  2021-04-02 08:12:52+00:00             μπουκίτσες με τυρί κρέμα
# 1370979 2021-04-12 08:28:38+00:00              κουλούρι κλασικό αφράτο
# 1370980 2021-04-12 08:28:38+00:00             κουλούρι κλασικό τραγανό
# 1370981 2021-04-12 08:28:38+00:00             μπουκίτσες με τυρί κρέμα
# 1394340 2021-05-13 08:15:09+00:00             μπουκίτσες με τυρί κρέμα
# 1394341 2021-05-13 08:15:09+00:00             κουλούρι κλασικό τραγανό
# 1394342 2021-05-13 08:15:09+00:00  κουλούρι gouda γεμιστό με τυρί arla
#
#                                  category_name  item_price  item_quantity  \
# 137735   Goody`s Signatures Wraps & Sandwiches         5.5              1
# 137736                                  Παγωτά         2.7              1
# 228488                               Νηστίσιμα         0.5              2
# 228489                               Νηστίσιμα         0.5             15
# 228490            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 255343                               Νηστίσιμα         0.5             10
# 255344            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 255345                        Κουλούρια αλμυρά         1.0              3
# 285646                        Κουλούρια αλμυρά         1.0              2
# 285647            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 285648                               Νηστίσιμα         0.5              1
# 285649                               Νηστίσιμα         0.5             15
# 315984            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 315985                               Νηστίσιμα         0.5             10
# 315986                        Κουλούρια αλμυρά         1.0              1
# 423524            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 423525                               Νηστίσιμα         0.5              2
# 423526                               Νηστίσιμα         0.5             15
# 447536                                  Παγωτά         2.7              1
# 447537   Goody`s Signatures Wraps & Sandwiches         5.5              1
# 449760                               Νηστίσιμα         0.5              2
# 449761                               Νηστίσιμα         0.5              9
# 449762                        Κουλούρια αλμυρά         1.0              2
# 533557                               Νηστίσιμα         0.5              2
# 533558                               Νηστίσιμα         1.0              1
# 533559                               Νηστίσιμα         0.5             10
# 533560            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 555652                               Νηστίσιμα         0.5              2
# 555653                               Νηστίσιμα         0.5             15
# 555654            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 585478                               Νηστίσιμα         0.5              2
# 585479                               Νηστίσιμα         0.5             15
# 585480            Κουλούρια μπουκίτσες γεμιστά         0.6              8
# 598909                        Κουλούρια αλμυρά         1.0              2
# 598910            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 598911                               Νηστίσιμα         0.5             15
# 613285                        Κουλούρια αλμυρά         1.0              2
# 613286            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 613287                               Νηστίσιμα         0.5             15
# 759997                        Κουλούρια αλμυρά         1.0              2
# 759998            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 759999                               Νηστίσιμα         0.5             15
# 881974                               Νηστίσιμα         0.5              2
# 881975                               Νηστίσιμα         0.5             15
# 881976            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 915177                               Νηστίσιμα         0.5              2
# 915178                              Sandwiches         1.0              1
# 915179                               Νηστίσιμα         0.5             15
# 915180                        Κουλούρια αλμυρά         1.0              2
# 921132                               Νηστίσιμα         0.5              2
# 921133                               Νηστίσιμα         0.5             15
# 921134            Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 1370979                              Νηστίσιμα         0.5              2
# 1370980                              Νηστίσιμα         0.5             15
# 1370981           Κουλούρια μπουκίτσες γεμιστά         0.6              8
# 1394340           Κουλούρια μπουκίτσες γεμιστά         0.6              6
# 1394341                              Νηστίσιμα         0.5             10
# 1394342                       Κουλούρια αλμυρά         2.0              3
#
#                                   shop_id  shop_is_chain  delivered_by_efood  \
# 137735   e641ac1140fda157d70b14889217ef31              1                   0
# 137736   e641ac1140fda157d70b14889217ef31              1                   0
# 228488   9328089b1989cda3a41065464a53bd60              1                   1
# 228489   9328089b1989cda3a41065464a53bd60              1                   1
# 228490   9328089b1989cda3a41065464a53bd60              1                   1
# 255343   9328089b1989cda3a41065464a53bd60              1                   1
# 255344   9328089b1989cda3a41065464a53bd60              1                   1
# 255345   9328089b1989cda3a41065464a53bd60              1                   1
# 285646   9328089b1989cda3a41065464a53bd60              1                   1
# 285647   9328089b1989cda3a41065464a53bd60              1                   1
# 285648   9328089b1989cda3a41065464a53bd60              1                   1
# 285649   9328089b1989cda3a41065464a53bd60              1                   1
# 315984   9328089b1989cda3a41065464a53bd60              1                   1
# 315985   9328089b1989cda3a41065464a53bd60              1                   1
# 315986   9328089b1989cda3a41065464a53bd60              1                   1
# 423524   9328089b1989cda3a41065464a53bd60              1                   1
# 423525   9328089b1989cda3a41065464a53bd60              1                   1
# 423526   9328089b1989cda3a41065464a53bd60              1                   1
# 447536   e641ac1140fda157d70b14889217ef31              1                   0
# 447537   e641ac1140fda157d70b14889217ef31              1                   0
# 449760   9328089b1989cda3a41065464a53bd60              1                   1
# 449761   9328089b1989cda3a41065464a53bd60              1                   1
# 449762   9328089b1989cda3a41065464a53bd60              1                   1
# 533557   9328089b1989cda3a41065464a53bd60              1                   1
# 533558   9328089b1989cda3a41065464a53bd60              1                   1
# 533559   9328089b1989cda3a41065464a53bd60              1                   1
# 533560   9328089b1989cda3a41065464a53bd60              1                   1
# 555652   9328089b1989cda3a41065464a53bd60              1                   1
# 555653   9328089b1989cda3a41065464a53bd60              1                   1
# 555654   9328089b1989cda3a41065464a53bd60              1                   1
# 585478   9328089b1989cda3a41065464a53bd60              1                   1
# 585479   9328089b1989cda3a41065464a53bd60              1                   1
# 585480   9328089b1989cda3a41065464a53bd60              1                   1
# 598909   9328089b1989cda3a41065464a53bd60              1                   1
# 598910   9328089b1989cda3a41065464a53bd60              1                   1
# 598911   9328089b1989cda3a41065464a53bd60              1                   1
# 613285   9328089b1989cda3a41065464a53bd60              1                   1
# 613286   9328089b1989cda3a41065464a53bd60              1                   1
# 613287   9328089b1989cda3a41065464a53bd60              1                   1
# 759997   9328089b1989cda3a41065464a53bd60              1                   1
# 759998   9328089b1989cda3a41065464a53bd60              1                   1
# 759999   9328089b1989cda3a41065464a53bd60              1                   1
# 881974   9328089b1989cda3a41065464a53bd60              1                   1
# 881975   9328089b1989cda3a41065464a53bd60              1                   1
# 881976   9328089b1989cda3a41065464a53bd60              1                   1
# 915177   9328089b1989cda3a41065464a53bd60              1                   1
# 915178   9328089b1989cda3a41065464a53bd60              1                   1
# 915179   9328089b1989cda3a41065464a53bd60              1                   1
# 915180   9328089b1989cda3a41065464a53bd60              1                   1
# 921132   9328089b1989cda3a41065464a53bd60              1                   1
# 921133   9328089b1989cda3a41065464a53bd60              1                   1
# 921134   9328089b1989cda3a41065464a53bd60              1                   1
# 1370979  9328089b1989cda3a41065464a53bd60              1                   1
# 1370980  9328089b1989cda3a41065464a53bd60              1                   1
# 1370981  9328089b1989cda3a41065464a53bd60              1                   1
# 1394340  9328089b1989cda3a41065464a53bd60              1                   1
# 1394341  9328089b1989cda3a41065464a53bd60              1                   1
# 1394342  9328089b1989cda3a41065464a53bd60              1                   1
#
#         shop_cuisine  is_online_payment  order_has_discount_coupon  \
# 137735       Burgers                  0                          0
# 137736       Burgers                  0                          0
# 228488     Κουλούρια                  1                          0
# 228489     Κουλούρια                  1                          0
# 228490     Κουλούρια                  1                          0
# 255343     Κουλούρια                  1                          0
# 255344     Κουλούρια                  1                          0
# 255345     Κουλούρια                  1                          0
# 285646     Κουλούρια                  1                          0
# 285647     Κουλούρια                  1                          0
# 285648     Κουλούρια                  1                          0
# 285649     Κουλούρια                  1                          0
# 315984     Κουλούρια                  1                          0
# 315985     Κουλούρια                  1                          0
# 315986     Κουλούρια                  1                          0
# 423524     Κουλούρια                  1                          0
# 423525     Κουλούρια                  1                          0
# 423526     Κουλούρια                  1                          0
# 447536       Burgers                  1                          0
# 447537       Burgers                  1                          0
# 449760     Κουλούρια                  1                          0
# 449761     Κουλούρια                  1                          0
# 449762     Κουλούρια                  1                          0
# 533557     Κουλούρια                  1                          0
# 533558     Κουλούρια                  1                          0
# 533559     Κουλούρια                  1                          0
# 533560     Κουλούρια                  1                          0
# 555652     Κουλούρια                  1                          0
# 555653     Κουλούρια                  1                          0
# 555654     Κουλούρια                  1                          0
# 585478     Κουλούρια                  1                          0
# 585479     Κουλούρια                  1                          0
# 585480     Κουλούρια                  1                          0
# 598909     Κουλούρια                  1                          0
# 598910     Κουλούρια                  1                          0
# 598911     Κουλούρια                  1                          0
# 613285     Κουλούρια                  1                          0
# 613286     Κουλούρια                  1                          0
# 613287     Κουλούρια                  1                          0
# 759997     Κουλούρια                  1                          0
# 759998     Κουλούρια                  1                          0
# 759999     Κουλούρια                  1                          0
# 881974     Κουλούρια                  1                          0
# 881975     Κουλούρια                  1                          0
# 881976     Κουλούρια                  1                          0
# 915177     Κουλούρια                  1                          0
# 915178     Κουλούρια                  1                          0
# 915179     Κουλούρια                  1                          0
# 915180     Κουλούρια                  1                          0
# 921132     Κουλούρια                  1                          0
# 921133     Κουλούρια                  1                          0
# 921134     Κουλούρια                  1                          0
# 1370979    Κουλούρια                  1                          0
# 1370980    Κουλούρια                  1                          0
# 1370981    Κουλούρια                  1                          0
# 1394340    Κουλούρια                  0                          0
# 1394341    Κουλούρια                  0                          0
# 1394342    Κουλούρια                  0                          0
#
#          order_from_pinata geographical_region_of_user shop_city  \
# 137735                   0                       Αθήνα     Αθήνα
# 137736                   0                       Αθήνα     Αθήνα
# 228488                   0                       Αθήνα     Αθήνα
# 228489                   0                       Αθήνα     Αθήνα
# 228490                   0                       Αθήνα     Αθήνα
# 255343                   0                       Αθήνα     Αθήνα
# 255344                   0                       Αθήνα     Αθήνα
# 255345                   0                       Αθήνα     Αθήνα
# 285646                   0                       Αθήνα     Αθήνα
# 285647                   0                       Αθήνα     Αθήνα
# 285648                   0                       Αθήνα     Αθήνα
# 285649                   0                       Αθήνα     Αθήνα
# 315984                   0                       Αθήνα     Αθήνα
# 315985                   0                       Αθήνα     Αθήνα
# 315986                   0                       Αθήνα     Αθήνα
# 423524                   0                       Αθήνα     Αθήνα
# 423525                   0                       Αθήνα     Αθήνα
# 423526                   0                       Αθήνα     Αθήνα
# 447536                   0                       Αθήνα     Αθήνα
# 447537                   0                       Αθήνα     Αθήνα
# 449760                   0                       Αθήνα     Αθήνα
# 449761                   0                       Αθήνα     Αθήνα
# 449762                   0                       Αθήνα     Αθήνα
# 533557                   0                       Αθήνα     Αθήνα
# 533558                   0                       Αθήνα     Αθήνα
# 533559                   0                       Αθήνα     Αθήνα
# 533560                   0                       Αθήνα     Αθήνα
# 555652                   0                       Αθήνα     Αθήνα
# 555653                   0                       Αθήνα     Αθήνα
# 555654                   0                       Αθήνα     Αθήνα
# 585478                   0                       Αθήνα     Αθήνα
# 585479                   0                       Αθήνα     Αθήνα
# 585480                   0                       Αθήνα     Αθήνα
# 598909                   0                       Αθήνα     Αθήνα
# 598910                   0                       Αθήνα     Αθήνα
# 598911                   0                       Αθήνα     Αθήνα
# 613285                   0                       Αθήνα     Αθήνα
# 613286                   0                       Αθήνα     Αθήνα
# 613287                   0                       Αθήνα     Αθήνα
# 759997                   0                       Αθήνα     Αθήνα
# 759998                   0                       Αθήνα     Αθήνα
# 759999                   0                       Αθήνα     Αθήνα
# 881974                   0                       Αθήνα     Αθήνα
# 881975                   0                       Αθήνα     Αθήνα
# 881976                   0                       Αθήνα     Αθήνα
# 915177                   0                       Αθήνα     Αθήνα
# 915178                   0                       Αθήνα     Αθήνα
# 915179                   0                       Αθήνα     Αθήνα
# 915180                   0                       Αθήνα     Αθήνα
# 921132                   0                       Αθήνα     Αθήνα
# 921133                   0                       Αθήνα     Αθήνα
# 921134                   0                       Αθήνα     Αθήνα
# 1370979                  0                       Αθήνα     Αθήνα
# 1370980                  0                       Αθήνα     Αθήνα
# 1370981                  0                       Αθήνα     Αθήνα
# 1394340                  0                       Αθήνα     Αθήνα
# 1394341                  0                       Αθήνα     Αθήνα
# 1394342                  0                       Αθήνα     Αθήνα
#
#         geographical_region_of_shop  food_score  delivery_score  \
# 137735               Αγία Παρασκευή         NaN             NaN
# 137736               Αγία Παρασκευή         NaN             NaN
# 228488               Αγία Παρασκευή         NaN             NaN
# 228489               Αγία Παρασκευή         NaN             NaN
# 228490               Αγία Παρασκευή         NaN             NaN
# 255343               Αγία Παρασκευή         NaN             NaN
# 255344               Αγία Παρασκευή         NaN             NaN
# 255345               Αγία Παρασκευή         NaN             NaN
# 285646               Αγία Παρασκευή         NaN             NaN
# 285647               Αγία Παρασκευή         NaN             NaN
# 285648               Αγία Παρασκευή         NaN             NaN
# 285649               Αγία Παρασκευή         NaN             NaN
# 315984               Αγία Παρασκευή         NaN             NaN
# 315985               Αγία Παρασκευή         NaN             NaN
# 315986               Αγία Παρασκευή         NaN             NaN
# 423524               Αγία Παρασκευή         NaN             NaN
# 423525               Αγία Παρασκευή         NaN             NaN
# 423526               Αγία Παρασκευή         NaN             NaN
# 447536               Αγία Παρασκευή         NaN             NaN
# 447537               Αγία Παρασκευή         NaN             NaN
# 449760               Αγία Παρασκευή         NaN             NaN
# 449761               Αγία Παρασκευή         NaN             NaN
# 449762               Αγία Παρασκευή         NaN             NaN
# 533557               Αγία Παρασκευή         NaN             NaN
# 533558               Αγία Παρασκευή         NaN             NaN
# 533559               Αγία Παρασκευή         NaN             NaN
# 533560               Αγία Παρασκευή         NaN             NaN
# 555652               Αγία Παρασκευή         NaN             NaN
# 555653               Αγία Παρασκευή         NaN             NaN
# 555654               Αγία Παρασκευή         NaN             NaN
# 585478               Αγία Παρασκευή         NaN             NaN
# 585479               Αγία Παρασκευή         NaN             NaN
# 585480               Αγία Παρασκευή         NaN             NaN
# 598909               Αγία Παρασκευή         NaN             NaN
# 598910               Αγία Παρασκευή         NaN             NaN
# 598911               Αγία Παρασκευή         NaN             NaN
# 613285               Αγία Παρασκευή         NaN             NaN
# 613286               Αγία Παρασκευή         NaN             NaN
# 613287               Αγία Παρασκευή         NaN             NaN
# 759997               Αγία Παρασκευή         NaN             NaN
# 759998               Αγία Παρασκευή         NaN             NaN
# 759999               Αγία Παρασκευή         NaN             NaN
# 881974               Αγία Παρασκευή         NaN             NaN
# 881975               Αγία Παρασκευή         NaN             NaN
# 881976               Αγία Παρασκευή         NaN             NaN
# 915177               Αγία Παρασκευή         NaN             NaN
# 915178               Αγία Παρασκευή         NaN             NaN
# 915179               Αγία Παρασκευή         NaN             NaN
# 915180               Αγία Παρασκευή         NaN             NaN
# 921132               Αγία Παρασκευή         NaN             NaN
# 921133               Αγία Παρασκευή         NaN             NaN
# 921134               Αγία Παρασκευή         NaN             NaN
# 1370979              Αγία Παρασκευή         NaN             NaN
# 1370980              Αγία Παρασκευή         NaN             NaN
# 1370981              Αγία Παρασκευή         NaN             NaN
# 1394340              Αγία Παρασκευή         NaN             NaN
# 1394341              Αγία Παρασκευή         NaN             NaN
# 1394342              Αγία Παρασκευή         NaN             NaN
#
#          service_score last_order_at first_order_at  year  month    dayname  \
# 137735             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 137736             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 228488             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 228489             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 228490             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 255343             NaN    2021-05-26     2021-03-17  2021    May     Friday
# 255344             NaN    2021-05-26     2021-03-17  2021    May     Friday
# 255345             NaN    2021-05-26     2021-03-17  2021    May     Friday
# 285646             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 285647             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 285648             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 285649             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 315984             NaN    2021-05-26     2021-03-17  2021    May    Tuesday
# 315985             NaN    2021-05-26     2021-03-17  2021    May    Tuesday
# 315986             NaN    2021-05-26     2021-03-17  2021    May    Tuesday
# 423524             NaN    2021-05-26     2021-03-17  2021  April   Thursday
# 423525             NaN    2021-05-26     2021-03-17  2021  April   Thursday
# 423526             NaN    2021-05-26     2021-03-17  2021  April   Thursday
# 447536             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 447537             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 449760             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 449761             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 449762             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 533557             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 533558             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 533559             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 533560             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 555652             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 555653             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 555654             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 585478             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 585479             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 585480             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 598909             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 598910             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 598911             NaN    2021-05-26     2021-03-17  2021    May     Monday
# 613285             NaN    2021-05-26     2021-03-17  2021    May     Friday
# 613286             NaN    2021-05-26     2021-03-17  2021    May     Friday
# 613287             NaN    2021-05-26     2021-03-17  2021    May     Friday
# 759997             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 759998             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 759999             NaN    2021-05-26     2021-03-17  2021    May  Wednesday
# 881974             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 881975             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 881976             NaN    2021-05-26     2021-03-17  2021  April     Monday
# 915177             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 915178             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 915179             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 915180             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 921132             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 921133             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 921134             NaN    2021-05-26     2021-03-17  2021  April     Friday
# 1370979            NaN    2021-05-26     2021-03-17  2021  April     Monday
# 1370980            NaN    2021-05-26     2021-03-17  2021  April     Monday
# 1370981            NaN    2021-05-26     2021-03-17  2021  April     Monday
# 1394340            NaN    2021-05-26     2021-03-17  2021    May   Thursday
# 1394341            NaN    2021-05-26     2021-03-17  2021    May   Thursday
# 1394342            NaN    2021-05-26     2021-03-17  2021    May   Thursday
#
#          hour  day  TotalSum part_of_the_day   timestamp  week  weekday  \
# 137735     15    2       5.5       Afternoon  2021-05-12    19        2
# 137736     15    2       2.7       Afternoon  2021-05-12    19        2
# 228488      8    4       1.0         Morning  2021-04-23    16        4
# 228489      8    4       7.5         Morning  2021-04-23    16        4
# 228490      8    4       3.6         Morning  2021-04-23    16        4
# 255343      8    4       5.0         Morning  2021-05-07    18        4
# 255344      8    4       3.6         Morning  2021-05-07    18        4
# 255345      8    4       3.0         Morning  2021-05-07    18        4
# 285646      8    0       2.0         Morning  2021-05-17    20        0
# 285647      8    0       3.6         Morning  2021-05-17    20        0
# 285648      8    0       0.5         Morning  2021-05-17    20        0
# 285649      8    0       7.5         Morning  2021-05-17    20        0
# 315984      8    1       3.6         Morning  2021-05-11    19        1
# 315985      8    1       5.0         Morning  2021-05-11    19        1
# 315986      8    1       1.0         Morning  2021-05-11    19        1
# 423524      8    3       3.6         Morning  2021-04-08    14        3
# 423525      8    3       1.0         Morning  2021-04-08    14        3
# 423526      8    3       7.5         Morning  2021-04-08    14        3
# 447536     15    4       2.7       Afternoon  2021-04-16    15        4
# 447537     15    4       5.5       Afternoon  2021-04-16    15        4
# 449760      8    2       1.0         Morning  2021-05-05    18        2
# 449761      8    2       4.5         Morning  2021-05-05    18        2
# 449762      8    2       2.0         Morning  2021-05-05    18        2
# 533557      8    0       1.0         Morning  2021-04-05    14        0
# 533558      8    0       1.0         Morning  2021-04-05    14        0
# 533559      8    0       5.0         Morning  2021-04-05    14        0
# 533560      8    0       3.6         Morning  2021-04-05    14        0
# 555652      8    0       1.0         Morning  2021-04-26    17        0
# 555653      8    0       7.5         Morning  2021-04-26    17        0
# 555654      8    0       3.6         Morning  2021-04-26    17        0
# 585478      8    4       1.0         Morning  2021-04-16    15        4
# 585479      8    4       7.5         Morning  2021-04-16    15        4
# 585480      8    4       4.8         Morning  2021-04-16    15        4
# 598909      8    0       2.0         Morning  2021-05-31    22        0
# 598910      8    0       3.6         Morning  2021-05-31    22        0
# 598911      8    0       7.5         Morning  2021-05-31    22        0
# 613285      8    4       2.0         Morning  2021-05-21    20        4
# 613286      8    4       3.6         Morning  2021-05-21    20        4
# 613287      8    4       7.5         Morning  2021-05-21    20        4
# 759997      8    2       2.0         Morning  2021-05-26    21        2
# 759998      8    2       3.6         Morning  2021-05-26    21        2
# 759999      8    2       7.5         Morning  2021-05-26    21        2
# 881974      8    0       1.0         Morning  2021-04-19    16        0
# 881975      8    0       7.5         Morning  2021-04-19    16        0
# 881976      8    0       3.6         Morning  2021-04-19    16        0
# 915177      8    4       1.0         Morning  2021-04-30    17        4
# 915178      8    4       1.0         Morning  2021-04-30    17        4
# 915179      8    4       7.5         Morning  2021-04-30    17        4
# 915180      8    4       2.0         Morning  2021-04-30    17        4
# 921132      8    4       1.0         Morning  2021-04-02    13        4
# 921133      8    4       7.5         Morning  2021-04-02    13        4
# 921134      8    4       3.6         Morning  2021-04-02    13        4
# 1370979     8    0       1.0         Morning  2021-04-12    15        0
# 1370980     8    0       7.5         Morning  2021-04-12    15        0
# 1370981     8    0       4.8         Morning  2021-04-12    15        0
# 1394340     8    3       3.6         Morning  2021-05-13    19        3
# 1394341     8    3       5.0         Morning  2021-05-13    19        3
# 1394342     8    3       6.0         Morning  2021-05-13    19        3
#
#          weekofyear  left_review
# 137735           19            0
# 137736           19            0
# 228488           16            0
# 228489           16            0
# 228490           16            0
# 255343           18            0
# 255344           18            0
# 255345           18            0
# 285646           20            0
# 285647           20            0
# 285648           20            0
# 285649           20            0
# 315984           19            0
# 315985           19            0
# 315986           19            0
# 423524           14            0
# 423525           14            0
# 423526           14            0
# 447536           15            0
# 447537           15            0
# 449760           18            0
# 449761           18            0
# 449762           18            0
# 533557           14            0
# 533558           14            0
# 533559           14            0
# 533560           14            0
# 555652           17            0
# 555653           17            0
# 555654           17            0
# 585478           15            0
# 585479           15            0
# 585480           15            0
# 598909           22            0
# 598910           22            0
# 598911           22            0
# 613285           20            0
# 613286           20            0
# 613287           20            0
# 759997           21            0
# 759998           21            0
# 759999           21            0
# 881974           16            0
# 881975           16            0
# 881976           16            0
# 915177           17            0
# 915178           17            0
# 915179           17            0
# 915180           17            0
# 921132           13            0
# 921133           13            0
# 921134           13            0
# 1370979          15            0
# 1370980          15            0
# 1370981          15            0
# 1394340          19            0
# 1394341          19            0
# 1394342          19            0

# %%
customers_df2['household_size'].value_counts()
# Out:
# Large Household              9190
# Small or Medium Household    7355
# Single or Couple             4302
# Small Household              2317
# Medium Household             1834
# Name: household_size, dtype: int64

# %%
customers_df2['household_size2'].value_counts()
# Out:
# Small or Medium Household    6349
# Medium Household             6267
# Small Household              6238
# Single or Couple             6144
# Name: household_size2, dtype: int64

# %%
# customers_df2['marital_status'].value_counts()

# %%
# customers_df2[customers_df2['marital_status']=='Family']

# %%
customers_df2[customers_df2['household_size']=='Large Household']
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# 8      0024b8e15cb74e9662a90acf254fa7d6        3    186.60          16
# 11     0034658999072772a49e8ca63055f83e        3    570.60          58
# 12     0036fe81d8e79e4feb8befb2f43783f1       19    182.40          11
# ...                                 ...      ...       ...         ...
# 24991  ffe5d1943222e427eb7a634086a8d478        7    389.25          19
# 24992  ffe7a339b76f0bf9f5ed4d3476ee8829        5    237.10          18
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 4             1972         23        135               58             7
# 8              684          3         61               17             3
# 11            1972         28        178               84             9
# 12            1636          7         51               22             5
# ...            ...        ...        ...              ...           ...
# 24991          155         17        106               60            10
# 24992         1426         15         66               35             6
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
#
#                                               categories  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...
# 8      [Eggs & pancake, Smoothies, Συσκευασμένοι χυμο...
# 11     [Αραβικές πίτες, My crepa, Club sandwich 5€, Κ...
# 12     [Νηστίσιμο menu, Καφέδες, Τεμάχια, Της πατάτας...
# ...                                                  ...
# 24991  [Sushi inside οut, Νερά, Κοτόπουλο, Σάντουιτς,...
# 24992  [My crepa, Σάντουιτς, Καφέδες, Σάντουιτς καλαμ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...
#
#                         city           region  \
# 0                  ['Αθήνα']        ['Αθήνα']
# 4                  ['Αθήνα']        ['Αθήνα']
# 8            ['Θεσσαλονίκη']  ['Θεσσαλονίκη']
# 11                 ['Αθήνα']        ['Αθήνα']
# 12                 ['Αθήνα']        ['Αθήνα']
# ...                      ...              ...
# 24991        ['Θεσσαλονίκη']  ['Θεσσαλονίκη']
# 24992  ['Πειραιάς', 'Αθήνα']     ['Πειραιάς']
# 24993              ['Αθήνα']        ['Αθήνα']
# 24994              ['Αθήνα']        ['Αθήνα']
# 24995              ['Αθήνα']        ['Αθήνα']
#
#                                             shop_regions  \
# 0                                         ['Νέα Σμύρνη']
# 4                        ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# 8                        ['Θεσσαλονίκη-Πυλαία-Πανόραμα']
# 11            ['Καλλιθέα-Ανατολικά', 'Βάρη-Βουλιαγμένη']
# 12                ['Χολαργός-Παπάγου', 'Αγία Παρασκευή']
# ...                                                  ...
# 24991  ['Θεσσαλονίκη-Πυλαία-Πανόραμα', 'Θεσσαλονίκη-Χ...
# 24992                                         ['Νίκαια']
# 24993  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994                                      ['Βριλήσσια']
# 24995                            ['Πετρούπολη-Καματερό']
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']      12.45
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...       9.72
# 8                       ['Sandwich', 'Καφέδες', 'Pizza']      11.66
# 11     ['Λουκουμάδες', 'Σουβλάκια', 'Μαγειρευτά', 'Κρ...       9.84
# 12     ['Σουβλάκια', 'Pizza', 'Καφέδες', 'Ζαχαροπλαστ...      16.58
# ...                                                  ...        ...
# 24991  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Cocktai...      20.49
# 24992  ['Σουβλάκια', 'Κρέπες', 'Καφέδες', 'Kebab', 'B...      13.17
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...      18.62
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']      10.32
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...      16.55
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                     4.41                          0.71              0.29
# 4                     2.87                          0.79              0.60
# 8                     3.81                          0.75              1.00
# 11                    3.07                          0.78              0.67
# 12                    4.64                          1.73              0.91
# ...                    ...                           ...               ...
# 24991                 5.58                          2.05              0.63
# 24992                 3.67                          1.61              0.33
# 24993                 3.83                          2.50              0.58
# 24994                 3.81                          1.69              0.88
# 24995                 4.20                          1.27              0.47
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                         0.00                       0.0              0.00
# 4                         0.00                       0.0              0.57
# 8                         0.00                       0.0              0.00
# 11                        0.00                       0.0              0.40
# 12                        0.00                       0.0              0.00
# ...                        ...                       ...               ...
# 24991                     0.26                       0.0              1.00
# 24992                     0.00                       0.0              0.33
# 24993                     0.17                       0.0              0.58
# 24994                     0.06                       0.0              0.25
# 24995                     0.00                       0.0              0.87
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0                  0.32               True          0.00            0.06
# 4                  0.00              False          0.02            0.21
# 8                  0.00              False          0.44            0.31
# 11                 0.19               True          0.40            0.45
# 12                 0.09              False          0.00            0.73
# ...                 ...                ...           ...             ...
# 24991              0.00              False          0.00            0.53
# 24992              0.00              False          0.00            0.22
# 24993              0.50              False          0.17            0.25
# 24994              0.00              False          0.00            0.50
# 24995              0.00              False          0.00            0.00
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0            0.94                      False           0.0  Mystery Maven
# 4            0.77                      False           0.0  Mystery Maven
# 8            0.25                      False           0.0  Mystery Maven
# 11           0.16                      False           0.0  Mystery Maven
# 12           0.27                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24991        0.47                      False           0.0  Mystery Maven
# 24992        0.78                      False           0.0  Mystery Maven
# 24993        0.58                      False           0.0  Mystery Maven
# 24994        0.50                      False           0.0  Mystery Maven
# 24995        1.00                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                    0.26                0.74                       Αθήνα
# 4                    0.32                0.68                       Αθήνα
# 8                    0.25                0.75                 Θεσσαλονίκη
# 11                   0.19                0.81                       Αθήνα
# 12                   0.55                0.45                       Αθήνα
# ...                   ...                 ...                         ...
# 24991                0.32                0.68                 Θεσσαλονίκη
# 24992                0.11                0.89                    Πειραιάς
# 24993                0.58                0.42                       Αθήνα
# 24994                0.25                0.75                       Αθήνα
# 24995                0.53                0.47                       Αθήνα
#
#        coffee_percentage  percentage_with_more_than_2             prefecture  \
# 0                   0.00                         0.38   νοτιος τομεας αθηνων
# 4                   0.19                         0.23   νοτιος τομεας αθηνων
# 8                   0.06                         1.00            θεσσαλονικη
# 11                  0.52                         0.12       ανατολικη αττικη
# 12                  0.27                         0.82  βορειος τομεας αθηνων
# ...                  ...                          ...                    ...
# 24991               0.21                         0.89            θεσσαλονικη
# 24992               0.06                         0.61               πειραιας
# 24993               0.25                         0.17  δυτικος τομεας αθηνων
# 24994               0.31                         0.12  βορειος τομεας αθηνων
# 24995               0.13                         0.40  δυτικος τομεας αθηνων
#
#          GDP  population    income_class            household_size2  \
# 0      18127      425112  Average income           Medium Household
# 4      18127      425112  Average income  Small or Medium Household
# 8      13091      884945  Average income           Medium Household
# 11     15987      403714  Average income  Small or Medium Household
# 12     25665      481758     High income           Medium Household
# ...      ...         ...             ...                        ...
# 24991  13091      884945  Average income           Medium Household
# 24992  18143      388480  Average income           Medium Household
# 24993  10608      405623      Low income           Medium Household
# 24994  25665      481758     High income           Medium Household
# 24995  10608      405623      Low income           Medium Household
#
#         household_size
# 0      Large Household
# 4      Large Household
# 8      Large Household
# 11     Large Household
# 12     Large Household
# ...                ...
# 24991  Large Household
# 24992  Large Household
# 24993  Large Household
# 24994  Large Household
# 24995  Large Household
#
# [9190 rows x 40 columns]

# %% [markdown]
# ## Cuisines exploration

# %% [markdown]
# ### Split customers based on how adventurous they are with their choices of food

# %%
test = pd.DataFrame(customers_df2.cuisines.values.tolist()).stack().value_counts()

# %%
top_5_lists = test.head(20)
top_5_lists
# Out:
# ['Καφέδες', 'Σουβλάκια']                                      550
# ['Pizza', 'Καφέδες', 'Σουβλάκια']                             442
# ['Σουβλάκια', 'Κρέπες', 'Pizza', 'Καφέδες', 'Burgers']        422
# ['Pizza', 'Σουβλάκια', 'Καφέδες']                             363
# ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']                  323
# ['Καφέδες']                                                   289
# ['Σουβλάκια', 'Καφέδες']                                      266
# ['Pizza', 'Σουβλάκια', 'Καφέδες', 'Burgers']                  257
# ['Καφέδες', 'Σουβλάκια', 'Burgers']                           226
# ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Καφέδες']                   210
# ['Pizza', 'Καφέδες', 'Κρέπες', 'Σουβλάκια']                   210
# ['Pizza', 'Σουβλάκια']                                        208
# ['Pizza', 'Σουβλάκια', 'Burgers']                             183
# ['Σουβλάκια', 'Κρέπες', 'Καφέδες']                            150
# ['Pizza', 'Καφέδες']                                          129
# ['Σουβλάκια', 'Μαγειρευτά', 'Pizza', 'Καφέδες', 'Burgers']    128
# ['Σουβλάκια', 'Καφέδες', 'Burgers']                           128
# ['Pizza', 'Σουβλάκια', 'Κρέπες']                              114
# ['Σουβλάκια']                                                 113
# ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Burgers']                   108
# dtype: int64

# %%
unique_cuisines = customers_df2['cuisines'].str.split(', ', expand=True).stack().value_counts().head(20).index
unique_cuisines
# Out:
# Index([''Καφέδες'', '['Σουβλάκια'', ''Pizza'', ''Κρέπες'', ''Burgers']',
#        ''Σουβλάκια'', ''Burgers'', ''Μαγειρευτά'', '['Pizza'', ''Sushi'',
#        ''Καφέδες']', ''Ψητά - Grill']', '['Καφέδες'', ''Κινέζικη'',
#        ''Σουβλάκια']', ''Ζαχαροπλαστείο'', ''Ζυμαρικά'', ''Brunch']',
#        ''Κοτόπουλα']', ''Ψητά - Grill''],
#       dtype='object')

# %%
top_20_cuisines = df.shop_cuisine.value_counts().head(20).index.tolist()
top_20_cuisines
# Out:
# ['Καφέδες',
#  'Σουβλάκια',
#  'Burgers',
#  'Pizza',
#  'Κρέπες',
#  'Μαγειρευτά',
#  'Ψητά - Grill',
#  'Sushi',
#  'Brunch',
#  'Αρτοποιήματα',
#  'Κουλούρια',
#  'Κινέζικη',
#  'Μπουγάτσα',
#  'Κοτόπουλα',
#  'Sandwich',
#  'Ζαχαροπλαστείο',
#  'Kebab',
#  'Ζυμαρικά',
#  'Ασιατική',
#  'Θαλασσινά']

# %%
bottom_5_lists = test.tail(20)
bottom_5_lists
# Out:
# ['Αρτοποιήματα', 'Σουβλάκια', 'Μαγειρευτά', 'Ζυμαρικά', 'Pizza', 'Καφέδες', 'Burgers', 'Brunch']                                                                              1
# ['Pizza', 'Μπουγάτσα', 'Καφέδες', 'Ζαχαροπλαστείο', 'Burgers', 'Κοτόπουλα']                                                                                                   1
# ['Αρτοποιήματα', 'Σουβλάκια', 'Κρέπες', 'Ζυμαρικά', 'Cocktails', 'Pizza', 'Παγωτό', 'Κινέζικη', 'Καφέδες']                                                                    1
# ['Σουβλάκια', 'Cocktails', 'Ασιατική', 'Καφέδες', 'Θαλασσινά', 'Burgers']                                                                                                     1
# ['Σουβλάκια', 'Κρέπες', 'Pizza', 'Κινέζικη', 'Καφέδες', 'Sushi', 'Kebab', 'Γλυκά', 'Burgers', 'Κοτόπουλα']                                                                    1
# ['Λουκουμάδες', 'Σουβλάκια', 'Κρέπες', 'Pizza', 'Παγωτό', 'Μπουγάτσα', 'Καφέδες', 'Sushi', 'Σαλάτες', 'Burgers', 'Ψητά - Grill']                                              1
# ['Snacks', 'Σουβλάκια', 'Κρέπες', 'Κινέζικη', 'Καφέδες', 'Burgers', 'Brunch']                                                                                                 1
# ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Ασιατική', 'Ethnic', 'Pizza', 'Μεζεδοπωλείο', 'Θαλασσινά', 'Γλυκά', 'Sandwich', 'Ψητά - Grill', 'Ελληνική', 'Burgers', 'Κοτόπουλα']    1
# ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Φρέσκοι χυμοί', 'Snacks', 'Πεϊνιρλί', 'Pizza', 'Μπουγάτσα', 'Καφέδες', 'Ζαχαροπλαστείο', 'Sushi', 'Burgers', 'Donuts', 'Κοτόπουλα']    1
# ['Αρτοποιήματα', 'Σουβλάκια', 'Ιταλική', 'Παγωτό', 'Κινέζικη', 'Καφέδες', 'Θαλασσινά', 'Burgers', 'Ψητά - Grill', 'Κοτόπουλα']                                                1
# ['Σουβλάκια', 'Πιροσκί', 'Καφέδες', 'Θαλασσινά', 'Ψητά - Grill', 'Κοτόπουλα']                                                                                                 1
# ['Ψητά - Grill', 'Σουβλάκια', 'Vegan', 'Καφέδες']                                                                                                                             1
# ['Σουβλάκια', 'Φαλάφελ', 'Καφέδες', 'Γλυκά', 'Burgers']                                                                                                                       1
# ['Σουβλάκια', 'Ινδική', 'Καφέδες', 'Sushi', 'Burgers']                                                                                                                        1
# ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Ιταλική', 'Cocktails', 'Ασιατική', 'Pizza', 'Hot Dog', 'Κινέζικη', 'Καφέδες', 'Sushi', 'Burgers', 'Brunch']                            1
# ['Παγωτό', 'Καφέδες', 'Σουβλάκια', 'Ασιατική']                                                                                                                                1
# ['Σουβλάκια', 'Μαγειρευτά', 'Pizza', 'Καφέδες', 'Ζαχαροπλαστείο', 'Sushi', 'Ψητά - Grill', 'Κοτόπουλα']                                                                       1
# ['Καφέδες', 'Ζαχαροπλαστείο', 'Σουβλάκια', 'Ιταλική']                                                                                                                         1
# ['Καφέδες', 'Μαγειρευτά', 'Σαλάτες', 'Burgers']                                                                                                                               1
# ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', 'Pizza', 'Καφέδες', 'Burgers']                                                                                                   1
# dtype: int64

# %%
for list_name, count in top_5_lists.items():
    print(f"{list_name}: {count}")
# Out:
# ['Καφέδες', 'Σουβλάκια']: 550
# ['Pizza', 'Καφέδες', 'Σουβλάκια']: 442
# ['Σουβλάκια', 'Κρέπες', 'Pizza', 'Καφέδες', 'Burgers']: 422
# ['Pizza', 'Σουβλάκια', 'Καφέδες']: 363
# ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']: 323
# ['Καφέδες']: 289
# ['Σουβλάκια', 'Καφέδες']: 266
# ['Pizza', 'Σουβλάκια', 'Καφέδες', 'Burgers']: 257
# ['Καφέδες', 'Σουβλάκια', 'Burgers']: 226
# ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Καφέδες']: 210
# ['Pizza', 'Καφέδες', 'Κρέπες', 'Σουβλάκια']: 210
# ['Pizza', 'Σουβλάκια']: 208
# ['Pizza', 'Σουβλάκια', 'Burgers']: 183
# ['Σουβλάκια', 'Κρέπες', 'Καφέδες']: 150
# ['Pizza', 'Καφέδες']: 129
# ['Σουβλάκια', 'Μαγειρευτά', 'Pizza', 'Καφέδες', 'Burgers']: 128
# ['Σουβλάκια', 'Καφέδες', 'Burgers']: 128
# ['Pizza', 'Σουβλάκια', 'Κρέπες']: 114
# ['Σουβλάκια']: 113
# ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Burgers']: 108

# %%
# Calculate the total number of users in the dataset
total_users = len(customers_df2)

# Calculate the percentage of each list
list_percentages = (test.head(20) / total_users) * 100

# Print the top 5 lists and their corresponding percentages
for list_name, percentage in list_percentages.head(20).items():
    print(f"{list_name}: {percentage:.2f}%")
# Out:
# ['Καφέδες', 'Σουβλάκια']: 2.20%
# ['Pizza', 'Καφέδες', 'Σουβλάκια']: 1.77%
# ['Σουβλάκια', 'Κρέπες', 'Pizza', 'Καφέδες', 'Burgers']: 1.69%
# ['Pizza', 'Σουβλάκια', 'Καφέδες']: 1.45%
# ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']: 1.29%
# ['Καφέδες']: 1.16%
# ['Σουβλάκια', 'Καφέδες']: 1.06%
# ['Pizza', 'Σουβλάκια', 'Καφέδες', 'Burgers']: 1.03%
# ['Καφέδες', 'Σουβλάκια', 'Burgers']: 0.90%
# ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Καφέδες']: 0.84%
# ['Pizza', 'Καφέδες', 'Κρέπες', 'Σουβλάκια']: 0.84%
# ['Pizza', 'Σουβλάκια']: 0.83%
# ['Pizza', 'Σουβλάκια', 'Burgers']: 0.73%
# ['Σουβλάκια', 'Κρέπες', 'Καφέδες']: 0.60%
# ['Pizza', 'Καφέδες']: 0.52%
# ['Σουβλάκια', 'Μαγειρευτά', 'Pizza', 'Καφέδες', 'Burgers']: 0.51%
# ['Σουβλάκια', 'Καφέδες', 'Burgers']: 0.51%
# ['Pizza', 'Σουβλάκια', 'Κρέπες']: 0.46%
# ['Σουβλάκια']: 0.45%
# ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Burgers']: 0.43%

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Create a dictionary with the top 20 cuisine values as keys and their counts as values
cuisine_counts = dict(customers_df2['cuisines'].str.split(', ', expand=True).stack().value_counts().head(20))

# Define the WordCloud object with the desired parameters
wc = WordCloud(background_color='black', colormap='Reds', max_words=20)

# Generate the wordcloud using the cuisine_counts dictionary
wc.generate_from_frequencies(cuisine_counts)

# Display the wordcloud using matplotlib
plt.figure(figsize=(14,14))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
customers_df2['cuisine_diversity'] = customers_df2['num_cuisines'] / customers_df2['num_orders']

# %%
# Calculate the average number of shops, categories, and cuisines for each customer
customers_df2['avg_shops'] = customers_df2['num_shops'] / customers_df2['num_orders']

# %%
customers_df2.num_cuisines.describe()
# Out:
# count    24998.000000
# mean         5.252460
# std          2.315425
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          7.000000
# max         21.000000
# Name: num_cuisines, dtype: float64

# %%
customers_df2.avg_shops.describe()
# Out:
# count    24998.000000
# mean         0.488587
# std          0.206010
# min          0.015385
# 25%          0.333333
# 50%          0.476190
# 75%          0.636364
# max          1.000000
# Name: avg_shops, dtype: float64

# %%
customers_df2.cuisine_diversity.describe()
# Out:
# count    24998.000000
# mean         0.274096
# std          0.136662
# min          0.009009
# 25%          0.171429
# 50%          0.250000
# 75%          0.363005
# max          1.000000
# Name: cuisine_diversity, dtype: float64

# %%
# Define the labels based on the average values
def label_customer_on_cuisines(row):
    if row['avg_shops'] > 0.6 and row['cuisine_diversity'] > 0.33 and row['num_cuisines']>8:
        return 'Foodie'
    elif row['avg_shops'] > 0.4 and row['cuisine_diversity'] > 0.25  and row['num_cuisines']>5:
        return 'Adventurous'
    elif row['avg_shops'] > 0.1  and row['num_cuisines']>3:
        return 'Unadventurous'
    else:
        return 'Plain Jane/John'

# Apply the labels to each row in the DataFrame
customers_df2['foodie_label'] = customers_df2.apply(label_customer_on_cuisines, axis=1)

# %%
customers_df2['foodie_label'].value_counts()
# Out:
# Unadventurous      12978
# Plain Jane/John     5751
# Adventurous         5532
# Foodie               737
# Name: foodie_label, dtype: int64

# %%
customers_df2
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 0      0001496e540173a40362759ed10b3ce2        2    423.40          34
# 1      0003b7de618c1acfc67eac91b853b287        4    343.35          40
# 2      00045e9d1c96d7e2353f886704e51c88       13     43.80          13
# 3      000e223791e890e85938d71bee32cf5a        3    122.50          49
# 4      0016652ea3c3a1176dd2385e89de9ff6        2    456.70          47
# ...                                 ...      ...       ...         ...
# 24993  ffea41c4dcc53a7ffd316f22ddb97be7        3    223.45          12
# 24994  fff262fbc647360700cee69566e26989        3    165.15          16
# 24995  fff355794e97eaaf07f53f4fdb4d0cd2        3    248.20          15
# 24996  fffacf61b056a50e5cf7173b94c939df        2    133.60          20
# 24997  ffffac8ce4cdfb1e5bc28beb7d46f7d5        6    143.60          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 0              479         17        150               52             2
# 1             1273         23         99               61             9
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 4             1972         23        135               58             7
# ...            ...        ...        ...              ...           ...
# 24993         1901         11         46               39             7
# 24994         1126         10         61               39             4
# 24995         1265          7         63               35             5
# 24996         1183          8         48               21             6
# 24997          871          7         28               14             4
#
#                                               categories                city  \
# 0      [Θρακόψωμο 5€ Deals, Αραβικές πίτες, Σάντουιτς...           ['Αθήνα']
# 1      [Κοτόπουλο, Our Burger Meals | Single Burger, ...           ['Αθήνα']
# 2                    [Καφέδες, Club sandwiches, Burgers]          ['Κιλκίς']
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]          ['Σπάρτη']
# 4      [Hot dog, Sauces, Αναψυκτικά 330ml 5€ deals, M...           ['Αθήνα']
# ...                                                  ...                 ...
# 24993  [Κοτόπουλο, My crepa, Καφέδες, My waffle, Burg...           ['Αθήνα']
# 24994  [Καλαμάκια, Κοτόπουλο, Our Burger Meals | Sing...           ['Αθήνα']
# 24995  [Σάντουιτς, Καφέδες, Τεμάχια, Μπύρες | Ποτά, Μ...           ['Αθήνα']
# 24996  [Τυλιχτά προσφοράς Φάε με 5€, Κρουασάν σοκολάτ...  ['Πάτρα', 'Αθήνα']
# 24997  [Ζυμαρικά, Pancake σοκολάτα 1+1, 2 Extreme del...           ['Αθήνα']
#
#                    region                                       shop_regions  \
# 0               ['Αθήνα']                                     ['Νέα Σμύρνη']
# 1               ['Αθήνα']  ['Αθήνα-Ιλίσια-Μαβίλη', 'Παλαιό Φάληρο', 'Αθήν...
# 2              ['Κιλκίς']                                         ['Κιλκίς']
# 3              ['Σπάρτη']                                         ['Σπάρτη']
# 4               ['Αθήνα']                    ['Ηλιούπολη', 'Αθήνα-Παγκράτι']
# ...                   ...                                                ...
# 24993           ['Αθήνα']  ['Περιστέρι-Δυτικά', 'Νέα Ερυθραία-Εκάλη-Δροσι...
# 24994           ['Αθήνα']                                      ['Βριλήσσια']
# 24995           ['Αθήνα']                            ['Πετρούπολη-Καματερό']
# 24996  ['Πάτρα', 'Αθήνα']        ['Πάτρα 2', 'Αθήνα-Παγκράτι', 'Καισαριανή']
# 24997           ['Αθήνα']  ['Πετρούπολη-Καματερό', 'Αθήνα-Ομόνοια-Πλ. Βάθ...
#
#                                                 cuisines  avg_spent  \
# 0                            ['Σουβλάκια', 'Μαγειρευτά']      12.45
# 1      ['Σουβλάκια', 'Κουλούρια', 'Ζυμαρικά', 'Κρέπες...       8.58
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']       3.37
# 3                                   ['Pizza', 'Καφέδες']       2.50
# 4      ['Σουβλάκια', 'Κρέπες', 'Cocktails', 'Pizza', ...       9.72
# ...                                                  ...        ...
# 24993  ['Σουβλάκια', 'Βάφλες', 'Κρέπες', 'Ιταλική', '...      18.62
# 24994      ['Καφέδες', 'Κρέπες', 'Σουβλάκια', 'Burgers']      10.32
# 24995  ['Σουβλάκια', 'Ασιατική', 'Καφέδες', 'Burgers'...      16.55
# 24996  ['Σουβλάκια', 'Μαγειρευτά', 'Κρέπες', 'Pizza',...       6.68
# 24997       ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Burgers']       7.98
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 0                     4.41                          0.71              0.29
# 1                     2.48                          1.05              0.48
# 2                     1.00                          0.23              0.00
# 3                     1.10                          0.08              0.00
# 4                     2.87                          0.79              0.60
# ...                    ...                           ...               ...
# 24993                 3.83                          2.50              0.58
# 24994                 3.81                          1.69              0.88
# 24995                 4.20                          1.27              0.47
# 24996                 2.40                          1.15              0.70
# 24997                 1.56                          0.56              0.11
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 0                         0.00                       0.0              0.00
# 1                         0.15                       0.0              0.62
# 2                         0.00                       0.0              0.92
# 3                         0.00                       0.0              0.00
# 4                         0.00                       0.0              0.57
# ...                        ...                       ...               ...
# 24993                     0.17                       0.0              0.58
# 24994                     0.06                       0.0              0.25
# 24995                     0.00                       0.0              0.87
# 24996                     0.00                       0.0              0.40
# 24997                     0.00                       0.0              0.89
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 0                  0.32               True          0.00            0.06
# 1                  0.00              False          0.25            0.45
# 2                  0.00              False          0.38            0.15
# 3                  0.00              False          0.84            0.16
# 4                  0.00              False          0.02            0.21
# ...                 ...                ...           ...             ...
# 24993              0.50              False          0.17            0.25
# 24994              0.00              False          0.00            0.50
# 24995              0.00              False          0.00            0.00
# 24996              0.00              False          0.10            0.35
# 24997              0.06              False          0.56            0.17
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 0            0.94                      False           0.0  Mystery Maven
# 1            0.30                      False           0.0  Mystery Maven
# 2            0.46                      False           0.0  Mystery Maven
# 3            0.00                      False           0.0  Mystery Maven
# 4            0.77                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24993        0.58                      False           0.0  Mystery Maven
# 24994        0.50                      False           0.0  Mystery Maven
# 24995        1.00                      False           0.0  Mystery Maven
# 24996        0.55                      False           0.0  Mystery Maven
# 24997        0.28                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 0                    0.26                0.74                       Αθήνα
# 1                    0.22                0.78                       Αθήνα
# 2                    0.31                0.69                      Κιλκίς
# 3                    0.18                0.82                      Σπάρτη
# 4                    0.32                0.68                       Αθήνα
# ...                   ...                 ...                         ...
# 24993                0.58                0.42                       Αθήνα
# 24994                0.25                0.75                       Αθήνα
# 24995                0.53                0.47                       Αθήνα
# 24996                0.35                0.65                       Αθήνα
# 24997                0.11                0.89                       Αθήνα
#
#        coffee_percentage  percentage_with_more_than_2  \
# 0                   0.00                         0.38
# 1                   0.42                         0.18
# 2                   0.69                         0.00
# 3                   0.02                         0.00
# 4                   0.19                         0.23
# ...                  ...                          ...
# 24993               0.25                         0.17
# 24994               0.31                         0.12
# 24995               0.13                         0.40
# 24996               0.50                         0.00
# 24997               0.72                         0.06
#
#                     prefecture    GDP  population    income_class  \
# 0         νοτιος τομεας αθηνων  18127      425112  Average income
# 1         νοτιος τομεας αθηνων  18127      425112  Average income
# 2                       κιλκις  10609       85885      Low income
# 3                      λακωνια  11864       87104      Low income
# 4         νοτιος τομεας αθηνων  18127      425112  Average income
# ...                        ...    ...         ...             ...
# 24993    δυτικος τομεας αθηνων  10608      405623      Low income
# 24994    βορειος τομεας αθηνων  25665      481758     High income
# 24995    δυτικος τομεας αθηνων  10608      405623      Low income
# 24996                    αχαια  12370      296574      Low income
# 24997  κεντρικος τομεας αθηνων  30454      717373     High income
#
#                  household_size2             household_size  \
# 0               Medium Household            Large Household
# 1                Small Household  Small or Medium Household
# 2               Single or Couple           Single or Couple
# 3               Single or Couple           Single or Couple
# 4      Small or Medium Household            Large Household
# ...                          ...                        ...
# 24993           Medium Household            Large Household
# 24994           Medium Household            Large Household
# 24995           Medium Household            Large Household
# 24996            Small Household            Small Household
# 24997           Single or Couple           Single or Couple
#
#        cuisine_diversity  avg_shops     foodie_label
# 0               0.058824   0.500000  Plain Jane/John
# 1               0.225000   0.575000    Unadventurous
# 2               0.230769   0.307692  Plain Jane/John
# 3               0.040816   0.040816  Plain Jane/John
# 4               0.148936   0.489362    Unadventurous
# ...                  ...        ...              ...
# 24993           0.583333   0.916667      Adventurous
# 24994           0.250000   0.625000    Unadventurous
# 24995           0.333333   0.466667    Unadventurous
# 24996           0.300000   0.400000    Unadventurous
# 24997           0.222222   0.388889    Unadventurous
#
# [24998 rows x 43 columns]

# %% [markdown]
# ## Create bins according to how populous an area in Greece is

# %%
# Define bins for population segmentation
bins = [0, 90000, 250000, 450000, 500000, float('inf')]

# Create a new column for population segment
customers_df2['population_segment'] = pd.cut(customers_df2['population'], bins, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'], right=False)

# %%
customers_df2['population_segment'].value_counts()
# Out:
# Medium       10336
# Very High     7071
# Low           4062
# High          3097
# Very Low       432
# Name: population_segment, dtype: int64

# %%
customers_df2[customers_df2['population_segment']=='Very Low']
# Out:
#                             customer_id  recency  monetary  num_orders  \
# 2      00045e9d1c96d7e2353f886704e51c88       13      43.8          13
# 3      000e223791e890e85938d71bee32cf5a        3     122.5          49
# 70     00c4e6212562cccb2cf3d8cb88aadeff        3     157.2          19
# 98     01134609de2913d59778d41ec6b60533        4     155.5          18
# 137    016794f5d4800c7403bd1ed8d0f3b10b       21     371.2          23
# ...                                 ...      ...       ...         ...
# 24802  fe0d690eea11ed7f874e1f99fe03a245        5      99.2          14
# 24805  fe1a2a4032c3d087509dfd4493448b0e       12     232.3          23
# 24908  ff1a2e222c67aaa97bfa8f76aff27342        2      69.6          10
# 24934  ff4ebaab6661aff614b4e4528bc89da2        4      79.2          44
# 24942  ff633decc0f615a865acd4c437592d5e        7     175.4          18
#
#        days_active  num_shops  num_items  var_order_items  num_cuisines  \
# 2              263          4         13                5             3
# 3              501          2         54                5             2
# 70             234         10         74               26             5
# 98             567          9         49               15             4
# 137            904          3        105               19             3
# ...            ...        ...        ...              ...           ...
# 24802           51          2         30               12             2
# 24805         1203         10         78               26             4
# 24908         1297          9         21               17             4
# 24934          530          2         44                1             1
# 24942          396         12         52               30             4
#
#                                               categories  \
# 2                    [Καφέδες, Club sandwiches, Burgers]
# 3                [Καφέδες, Sandwiches, Σαλάτες, Burgers]
# 70     [Cheeseburger με πατάτες 5€ deals, Κουλούρια Θ...
# 98     [Pancakes γλυκά, Τηγανόψωμο, Κριτσίνια το κιλό...
# 137    [Λουκουμάδες, Ζυμαρικά, Pizza, Αναψυκτικά, Καφ...
# ...                                                  ...
# 24802  [Snacks, Αναψυκτικά, Καφέδες, Σαλάτες, Burgers...
# 24805  [Τυρόπιτα προσφοράς, My crepa, Καφέδες, Τεμάχι...
# 24908  [Σκεπαστές προσφοράς, Γλυκά κρουασάν, Espresso...
# 24934                                          [Καφέδες]
# 24942  [Καλτσόνε, My sandwich, Σκεπαστές προσφοράς, Σ...
#
#                                      city                              region  \
# 2                              ['Κιλκίς']                          ['Κιλκίς']
# 3                              ['Σπάρτη']                          ['Σπάρτη']
# 70     ['Άγιος Νικόλαος Κρήτη', 'Σέρρες']  ['Άγιος Νικόλαος Κρήτη', 'Σέρρες']
# 98                    ['Σπάρτη', 'Αθήνα']                 ['Σπάρτη', 'Αθήνα']
# 137                            ['Σπάρτη']                          ['Σπάρτη']
# ...                                   ...                                 ...
# 24802                          ['Κιλκίς']                          ['Κιλκίς']
# 24805                          ['Σπάρτη']                          ['Σπάρτη']
# 24908                    ['Αθήνα', 'Κως']                    ['Αθήνα', 'Κως']
# 24934                       ['Κεφαλονιά']                       ['Κεφαλονιά']
# 24942                   ['Κως', 'Λάρισα']                   ['Κως', 'Λάρισα']
#
#                               shop_regions  \
# 2                               ['Κιλκίς']
# 3                               ['Σπάρτη']
# 70     ['Άγιος Νικόλαος Κρήτης', 'Σέρρες']
# 98             ['Σπάρτη', 'Χαλάνδρι-Κάτω']
# 137                   ['Σπάρτη', 'Γύθειο']
# ...                                    ...
# 24802                           ['Κιλκίς']
# 24805                           ['Σπάρτη']
# 24908                    ['Κώς', 'Άλιμος']
# 24934                        ['Κεφαλονιά']
# 24942                    ['Κώς', 'Λάρισα']
#
#                                                 cuisines  avg_spent  \
# 2                         ['Pizza', 'Καφέδες', 'Κρέπες']       3.37
# 3                                   ['Pizza', 'Καφέδες']       2.50
# 70     ['Σουβλάκια', 'Pizza', 'Καφέδες', 'Burgers', '...       8.27
# 98       ['Pizza', 'Σουβλάκια', 'Μαγειρευτά', 'Καφέδες']       8.64
# 137                    ['Pizza', 'Σουβλάκια', 'Καφέδες']      16.14
# ...                                                  ...        ...
# 24802                           ['Σουβλάκια', 'Καφέδες']       7.09
# 24805        ['Pizza', 'Καφέδες', 'Σουβλάκια', 'Donuts']      10.10
# 24908    ['Καφέδες', 'Σουβλάκια', 'Κρέπες', 'Κοτόπουλα']       6.96
# 24934                                        ['Καφέδες']       1.80
# 24942        ['Pizza', 'Σουβλάκια', 'Κρέπες', 'Καφέδες']       9.74
#
#        avg_items_per_order  avg_num_categories_per_order  perc_chain_shops  \
# 2                     1.00                          0.23              0.00
# 3                     1.10                          0.08              0.00
# 70                    3.89                          1.05              0.21
# 98                    2.72                          0.67              0.17
# 137                   4.57                          0.52              0.00
# ...                    ...                           ...               ...
# 24802                 2.14                          0.43              0.00
# 24805                 3.39                          1.09              0.35
# 24908                 2.10                          1.10              0.20
# 24934                 1.00                          0.02              0.00
# 24942                 2.89                          1.00              0.28
#
#        perc_delivered_by_efood  perc_has_discount_coupon  perc_paid_online  \
# 2                          0.0                       0.0              0.92
# 3                          0.0                       0.0              0.00
# 70                         0.0                       0.0              0.42
# 98                         0.0                       0.0              0.00
# 137                        0.0                       0.0              0.52
# ...                        ...                       ...               ...
# 24802                      0.0                       0.0              1.00
# 24805                      0.0                       0.0              0.13
# 24908                      0.0                       0.0              0.40
# 24934                      0.0                       0.0              0.00
# 24942                      0.0                       0.0              0.67
#
#        perc_from_pinata  orders_every_week  morning_perc  afternoon_perc  \
# 2                  0.00              False          0.38            0.15
# 3                  0.00              False          0.84            0.16
# 70                 0.00              False          0.16            0.53
# 98                 0.06              False          0.17            0.56
# 137                0.00              False          0.04            0.04
# ...                 ...                ...           ...             ...
# 24802              0.00              False          0.00            0.64
# 24805              0.00              False          0.04            0.48
# 24908              0.00              False          0.10            0.20
# 24934              0.00               True          1.00            0.00
# 24942              0.00              False          0.17            0.44
#
#        night_perc  ordered_3_days_every_week  scores_count leaves_reviews  \
# 2            0.46                      False           0.0  Mystery Maven
# 3            0.00                      False           0.0  Mystery Maven
# 70           0.32                      False           0.0  Mystery Maven
# 98           0.28                      False           0.0  Mystery Maven
# 137          0.91                      False           0.0  Mystery Maven
# ...           ...                        ...           ...            ...
# 24802        0.36                      False           0.0  Mystery Maven
# 24805        0.48                      False           0.0  Mystery Maven
# 24908        0.70                      False           0.0  Mystery Maven
# 24934        0.00                      False           0.0  Mystery Maven
# 24942        0.39                      False           0.0  Mystery Maven
#
#        weekend_orders_pct  weekday_orders_pct geographical_region_of_user  \
# 2                    0.31                0.69                      Κιλκίς
# 3                    0.18                0.82                      Σπάρτη
# 70                   0.32                0.68        Άγιος Νικόλαος Κρήτη
# 98                   0.06                0.94                      Σπάρτη
# 137                  0.09                0.91                      Σπάρτη
# ...                   ...                 ...                         ...
# 24802                0.21                0.79                      Κιλκίς
# 24805                0.26                0.74                      Σπάρτη
# 24908                0.60                0.40                         Κως
# 24934                0.18                0.82                   Κεφαλονιά
# 24942                0.17                0.83                         Κως
#
#        coffee_percentage  percentage_with_more_than_2  prefecture    GDP  \
# 2                   0.69                         0.00      κιλκις  10609
# 3                   0.02                         0.00     λακωνια  11864
# 70                  0.26                         0.53       κρητη  12374
# 98                  0.39                         0.22     λακωνια  11864
# 137                 0.04                         0.87     λακωνια  11864
# ...                  ...                          ...         ...    ...
# 24802               0.29                         0.29      κιλκις  10609
# 24805               0.35                         0.22     λακωνια  11864
# 24908               0.40                         0.20         κως  12428
# 24934               1.00                         0.00  κεφαλληνια  13180
# 24942               0.39                         0.56         κως  12428
#
#        population    income_class            household_size2  \
# 2           85885      Low income           Single or Couple
# 3           87104      Low income           Single or Couple
# 70          73258      Low income           Medium Household
# 98          87104      Low income            Small Household
# 137         87104      Low income           Medium Household
# ...           ...             ...                        ...
# 24802       85885      Low income           Single or Couple
# 24805       87104      Low income  Small or Medium Household
# 24908       30322  Average income           Single or Couple
# 24934       37736  Average income           Single or Couple
# 24942       30322  Average income  Small or Medium Household
#
#                   household_size  cuisine_diversity  avg_shops  \
# 2               Single or Couple           0.230769   0.307692
# 3               Single or Couple           0.040816   0.040816
# 70              Medium Household           0.263158   0.526316
# 98     Small or Medium Household           0.222222   0.500000
# 137    Small or Medium Household           0.130435   0.130435
# ...                          ...                ...        ...
# 24802           Single or Couple           0.142857   0.142857
# 24805            Large Household           0.173913   0.434783
# 24908            Small Household           0.400000   0.900000
# 24934           Single or Couple           0.022727   0.045455
# 24942            Large Household           0.222222   0.666667
#
#           foodie_label population_segment
# 2      Plain Jane/John           Very Low
# 3      Plain Jane/John           Very Low
# 70       Unadventurous           Very Low
# 98       Unadventurous           Very Low
# 137    Plain Jane/John           Very Low
# ...                ...                ...
# 24802  Plain Jane/John           Very Low
# 24805    Unadventurous           Very Low
# 24908    Unadventurous           Very Low
# 24934  Plain Jane/John           Very Low
# 24942    Unadventurous           Very Low
#
# [432 rows x 44 columns]

# %%
# find rows with null values
null_mask = customers_df2.isnull().any(axis=1)
null_rows = customers_df2[null_mask]

# %%
null_rows
# Out:
# Empty DataFrame
# Columns: [customer_id, recency, monetary, num_orders, days_active, num_shops, num_items, var_order_items, num_cuisines, categories, city, region, shop_regions, cuisines, avg_spent, avg_items_per_order, avg_num_categories_per_order, perc_chain_shops, perc_delivered_by_efood, perc_has_discount_coupon, perc_paid_online, perc_from_pinata, orders_every_week, morning_perc, afternoon_perc, night_perc, ordered_3_days_every_week, scores_count, leaves_reviews, weekend_orders_pct, weekday_orders_pct, geographical_region_of_user, coffee_percentage, percentage_with_more_than_2, prefecture, GDP, population, income_class, household_size2, household_size, cuisine_diversity, avg_shops, foodie_label, population_segment]
# Index: []

# %%
# Calculate average purchase value by population segment
customers_df2.groupby('population_segment')['monetary'].mean()
# Out:
# population_segment
# Very Low     172.207454
# Low          187.475162
# Medium       225.234333
# High         257.702218
# Very High    222.286686
# Name: monetary, dtype: float64

# %%
# Calculate purchase frequency by population segment
customers_df2.groupby('population_segment')['num_orders'].mean()
# Out:
# population_segment
# Very Low     21.923611
# Low          22.512802
# Medium       23.415248
# High         22.880207
# Very High    22.799463
# Name: num_orders, dtype: float64

# %%
customers_df2.to_csv("customers_new.csv",index=False)
